# %% [markdown]
# # 서울특별시 공공자전거 이용정보 데이터 분석
#
# * 사용 데이터: 서울특별시 공공자전거 이용정보(월별)
# * 데이터 측정 기간: 2024년 7월~12월

# %%
import pandas as pd

# %% [markdown]
# # 1. 데이터 불러오기

# %%
data = pd.read_csv("data/서울특별시 공공자전거 이용정보(월별)_24.7-12.csv", encoding="CP949")
data
# Out:
#           대여일자  대여소번호                   대여소명 대여구분코드   성별 연령대코드  이용건수      운동량  \
# 0       202407    102        102. 망원역 1번출구 앞    일일권  NaN   20대    67  4304.28
# 1       202407    102        102. 망원역 1번출구 앞    일일권  NaN   30대    64  4142.09
# 2       202407    102        102. 망원역 1번출구 앞    일일권  NaN   40대     2   265.91
# 3       202407    102        102. 망원역 1번출구 앞    일일권  NaN   50대     6   648.52
# 4       202407    102        102. 망원역 1번출구 앞    일일권  NaN   60대     1    35.37
# ...        ...    ...                    ...    ...  ...   ...   ...      ...
# 619659  202412   6178  6178. 마스터밸류에이스 지식산업센터    정기권    M   40대    55  2964.38
# 619660  202412   6178  6178. 마스터밸류에이스 지식산업센터    정기권    M   50대    10   327.38
# 619661  202412   6178  6178. 마스터밸류에이스 지식산업센터    정기권    M   60대     1    14.37
# 619662  202412   6178  6178. 마스터밸류에이스 지식산업센터    정기권    M  ~10대     7   249.95
# 619663  202412   6178  6178. 마스터밸류에이스 지식산업센터    정기권    M    기타     6   135.89
#
#           탄소량    이동거리(M)  이용시간(분)
# 0       40.87  176252.62     1895
# 1       38.92  167774.15     1498
# 2        2.11    9098.64       64
# 3        5.11   22048.26      149
# 4        0.31    1333.18        6
# ...       ...        ...      ...
# 619659  23.14   99803.49     1050
# 619660   2.57   11073.52      183
# 619661   0.13     558.26        3
# 619662   2.35   10151.09       80
# 619663   1.16    5060.24       53
#
# [619664 rows x 11 columns]

# %%
print(data.shape)
# Out:
# (619664, 11)

# %%
print(data.columns)
# Out:
# Index(['대여일자', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량',
#        '이동거리(M)', '이용시간(분)'],
#       dtype='object')

# %% [markdown]
# # 2. 데이터 정보 확인하기

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 619664 entries, 0 to 619663
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   대여일자     619664 non-null  int64
#  1   대여소번호    619664 non-null  int64
#  2   대여소명     619664 non-null  object
#  3   대여구분코드   619664 non-null  object
#  4   성별       424280 non-null  object
#  5   연령대코드    619664 non-null  object
#  6   이용건수     619664 non-null  int64
#  7   운동량      619269 non-null  float64
#  8   탄소량      619269 non-null  float64
#  9   이동거리(M)  619664 non-null  float64
#  10  이용시간(분)  619664 non-null  int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 52.0+ MB

# %% [markdown]
# #### 대여일자를 datetime으로 바꾸지 않는 이유
# 우리가 분석하는 이 데이터는 일자별로 계속 측정이 된 게 아니라 **월별**로 집계된 데이터이기 때문에 이 데이터에서 대여일자는 카테고리라고 할 수 있다.

# %%
# 202407
pd.to_datetime(data["대여일자"], format="%Y%m")
# Out:
# 0        2024-07-01
# 1        2024-07-01
# 2        2024-07-01
# 3        2024-07-01
# 4        2024-07-01
#             ...
# 619659   2024-12-01
# 619660   2024-12-01
# 619661   2024-12-01
# 619662   2024-12-01
# 619663   2024-12-01
# Name: 대여일자, Length: 619664, dtype: datetime64[ns]

# %% [markdown]
# #### 데이터 형 변환을 해야 하는 이유
#
# int, float 타입으로 되어 있는 열은 `.describe()`라는 함수를 이용할 때 통계에 이용된다. 하지만 대여소번호와 같이 고유의 이름을 의미하는 경우에는 통계가 필요없기 때문에 object로 형 변환을 해줄 필요가 있다.

# %%
data.head()
# Out:
#      대여일자  대여소번호             대여소명 대여구분코드   성별 연령대코드  이용건수      운동량    탄소량  \
# 0  202407    102  102. 망원역 1번출구 앞    일일권  NaN   20대    67  4304.28  40.87
# 1  202407    102  102. 망원역 1번출구 앞    일일권  NaN   30대    64  4142.09  38.92
# 2  202407    102  102. 망원역 1번출구 앞    일일권  NaN   40대     2   265.91   2.11
# 3  202407    102  102. 망원역 1번출구 앞    일일권  NaN   50대     6   648.52   5.11
# 4  202407    102  102. 망원역 1번출구 앞    일일권  NaN   60대     1    35.37   0.31
#
#      이동거리(M)  이용시간(분)
# 0  176252.62     1895
# 1  167774.15     1498
# 2    9098.64       64
# 3   22048.26      149
# 4    1333.18        6

# %%
data.describe()
# Out:
#                 대여일자          대여소번호           이용건수            운동량  \
# count  619664.000000  619664.000000  619664.000000  619269.000000
# mean   202409.460550    2372.396744      36.207324    2171.806347
# std         1.679584    1606.029446      68.309988    4094.071706
# min    202407.000000     102.000000       1.000000       0.000000
# 25%    202408.000000    1003.000000       4.000000     221.250000
# 50%    202409.000000    2060.000000      12.000000     773.460000
# 75%    202411.000000    3816.000000      39.000000    2391.900000
# max    202412.000000    6178.000000    2454.000000  271725.720000
#
#                  탄소량       이동거리(M)        이용시간(분)
# count  619269.000000  6.196640e+05  619664.000000
# mean       18.868742  8.161182e+04     741.158513
# std        34.935409  1.511538e+05    1343.878371
# min         0.000000  0.000000e+00       0.000000
# 25%         2.010000  8.705685e+03      81.000000
# 50%         6.950000  3.007392e+04     274.000000
# 75%        21.140000  9.141029e+04     827.000000
# max      2652.600000  1.154394e+07   95970.000000

# %% [markdown]
# ## 1) 데이터 형 변환

# %% [markdown]
# * 대여일자: 202507 -> datetime으로 바꾸고 싶다. (위를 참고하여 object로 변경)
# * 대여소번호: 고유의 번호이기 때문에 object로 바꾸고 싶다.

# %%
# .astype()
new_data = data.astype({"대여일자": "object", "대여소번호": "object"})
new_data.dtypes
# Out:
# 대여일자        object
# 대여소번호       object
# 대여소명        object
# 대여구분코드      object
# 성별          object
# 연령대코드       object
# 이용건수         int64
# 운동량        float64
# 탄소량        float64
# 이동거리(M)    float64
# 이용시간(분)      int64
# dtype: object

# %% [markdown]
# ## 2) 카테고리 변수 unique 확인하기

# %% [markdown]
# * 카테고리로 표현되는 변수는 성별, 연령대코드이다.
# * 어떤 종류가 있는지 살펴보려고 한다.

# %%
# .unique(), .nunique()
new_data["성별"].unique()
# Out:
# array([nan, 'F', 'M', 'm', 'f'], dtype=object)

# %% [markdown]
# * 성별에 결측치가 많다. -> 응답하지 않은 내용이기 때문이다 "O" 새로운 카테고리를 만들자.
# * 대문자, 소문자가 섞여 있다. -> 대문자로 통일하자.

# %%
new_data["성별"] = data["성별"].str.upper()        # 대문자로 바꾸기
new_data["성별"] = new_data["성별"].fillna("O")    # 결측치 채우기
new_data["성별"].unique()
# Out:
# array(['O', 'F', 'M'], dtype=object)

# %%
new_data["연령대코드"].unique()
# Out:
# array(['20대', '30대', '40대', '50대', '60대', '기타', '~10대', '70대이상'],
#       dtype=object)

# %% [markdown]
# # 3. 결측치 확인하기

# %% [markdown]
# ## 원본 데이터

# %%
# 전체 데이터에 대한 결측치 확인
nan_result = data.isna().sum(axis=0)
nan_result
# Out:
# 대여일자            0
# 대여소번호           0
# 대여소명            0
# 대여구분코드          0
# 성별         195384
# 연령대코드           0
# 이용건수            0
# 운동량           395
# 탄소량           395
# 이동거리(M)         0
# 이용시간(분)         0
# dtype: int64

# %%
# nan_result에서 성별의 결측치 개수를 구하고 싶다.
nan_result["성별"]
# Out:
# np.int64(195384)

# %% [markdown]
# ## new_data

# %%
new_data.isna().sum()
# Out:
# 대여일자         0
# 대여소번호        0
# 대여소명         0
# 대여구분코드       0
# 성별           0
# 연령대코드        0
# 이용건수         0
# 운동량        395
# 탄소량        395
# 이동거리(M)      0
# 이용시간(분)      0
# dtype: int64

# %% [markdown]
# #### QA 넘파이로 결측치 구하기

# %%
import numpy as np

numeric_df = data.select_dtypes(include=[np.number])
numeric_df
# Out:
#           대여일자  대여소번호  이용건수      운동량    탄소량    이동거리(M)  이용시간(분)
# 0       202407    102    67  4304.28  40.87  176252.62     1895
# 1       202407    102    64  4142.09  38.92  167774.15     1498
# 2       202407    102     2   265.91   2.11    9098.64       64
# 3       202407    102     6   648.52   5.11   22048.26      149
# 4       202407    102     1    35.37   0.31    1333.18        6
# ...        ...    ...   ...      ...    ...        ...      ...
# 619659  202412   6178    55  2964.38  23.14   99803.49     1050
# 619660  202412   6178    10   327.38   2.57   11073.52      183
# 619661  202412   6178     1    14.37   0.13     558.26        3
# 619662  202412   6178     7   249.95   2.35   10151.09       80
# 619663  202412   6178     6   135.89   1.16    5060.24       53
#
# [619664 rows x 7 columns]

# %%
np.isnan(numeric_df).sum()
# Out:
# 대여일자         0
# 대여소번호        0
# 이용건수         0
# 운동량        395
# 탄소량        395
# 이동거리(M)      0
# 이용시간(분)      0
# dtype: int64

# %%
np.isnan(numeric_df).sum().sum()
# Out:
# np.int64(790)

# %%
nan_count = np.isnan(numeric_df).sum().sum()
print(f"숫자형에서 NaN 개수: {nan_count}")
# Out:
# 숫자형에서 NaN 개수: 790

# %% [markdown]
# # 4. 데이터 탐색

# %%
new_data.head()
# Out:
#      대여일자 대여소번호             대여소명 대여구분코드 성별 연령대코드  이용건수      운동량    탄소량  \
# 0  202407   102  102. 망원역 1번출구 앞    일일권  O   20대    67  4304.28  40.87
# 1  202407   102  102. 망원역 1번출구 앞    일일권  O   30대    64  4142.09  38.92
# 2  202407   102  102. 망원역 1번출구 앞    일일권  O   40대     2   265.91   2.11
# 3  202407   102  102. 망원역 1번출구 앞    일일권  O   50대     6   648.52   5.11
# 4  202407   102  102. 망원역 1번출구 앞    일일권  O   60대     1    35.37   0.31
#
#      이동거리(M)  이용시간(분)
# 0  176252.62     1895
# 1  167774.15     1498
# 2    9098.64       64
# 3   22048.26      149
# 4    1333.18        6

# %% [markdown]
# ## 1) 새로운 열 만들기

# %% [markdown]
# <div>
#     <img src="https://www.dropbox.com/scl/fi/3s8gvus21mqhcbqkz38zf/.png?rlkey=1kw3p6nleovg9dw6m82ik9izo&dl=1" width="90%">
# </div>

# %%
# 건당 이동거리(M), 건당 이용시간(분) 열을 추가
# 건당 이동거리(M) = 이동거리(M) / 이용건수
# 건당 이용시간(분) = 이용시간(분) / 이용건수
new_data["건당 이동거리(M)"] = new_data["이동거리(M)"] / new_data["이용건수"]
new_data["건당 이용시간(분)"] = new_data["이용시간(분)"] / new_data["이용건수"]

new_data.head()
# Out:
#      대여일자 대여소번호             대여소명 대여구분코드 성별 연령대코드  이용건수      운동량    탄소량  \
# 0  202407   102  102. 망원역 1번출구 앞    일일권  O   20대    67  4304.28  40.87
# 1  202407   102  102. 망원역 1번출구 앞    일일권  O   30대    64  4142.09  38.92
# 2  202407   102  102. 망원역 1번출구 앞    일일권  O   40대     2   265.91   2.11
# 3  202407   102  102. 망원역 1번출구 앞    일일권  O   50대     6   648.52   5.11
# 4  202407   102  102. 망원역 1번출구 앞    일일권  O   60대     1    35.37   0.31
#
#      이동거리(M)  이용시간(분)   건당 이동거리(M)  건당 이용시간(분)
# 0  176252.62     1895  2630.636119   28.283582
# 1  167774.15     1498  2621.471094   23.406250
# 2    9098.64       64  4549.320000   32.000000
# 3   22048.26      149  3674.710000   24.833333
# 4    1333.18        6  1333.180000    6.000000

# %%
# head(6): 2024년 7월에 102번 대여소, 일일권, 성별 없는 건들의 집계 데이터
test_data = new_data.head(6)
test_data
# Out:
#      대여일자 대여소번호             대여소명 대여구분코드 성별 연령대코드  이용건수      운동량    탄소량  \
# 0  202407   102  102. 망원역 1번출구 앞    일일권  O   20대    67  4304.28  40.87
# 1  202407   102  102. 망원역 1번출구 앞    일일권  O   30대    64  4142.09  38.92
# 2  202407   102  102. 망원역 1번출구 앞    일일권  O   40대     2   265.91   2.11
# 3  202407   102  102. 망원역 1번출구 앞    일일권  O   50대     6   648.52   5.11
# 4  202407   102  102. 망원역 1번출구 앞    일일권  O   60대     1    35.37   0.31
# 5  202407   102  102. 망원역 1번출구 앞    일일권  O    기타    23  1922.74  19.53
#
#      이동거리(M)  이용시간(분)   건당 이동거리(M)  건당 이용시간(분)
# 0  176252.62     1895  2630.636119   28.283582
# 1  167774.15     1498  2621.471094   23.406250
# 2    9098.64       64  4549.320000   32.000000
# 3   22048.26      149  3674.710000   24.833333
# 4    1333.18        6  1333.180000    6.000000
# 5   84195.84      791  3660.688696   34.391304

# %%
# 평균 이동거리(M)
# 이동거리의 합 / 이용건 수
test_data["이동거리(M)"].sum() / test_data["이용건수"].sum()
# Out:
# np.float64(2826.3968711656444)

# %%
# 건당 이동거리(M)
# 각 행의 이동거리(M) / 이용건수
# 이 의미는 무엇일까?
test_data["건당 이동거리(M)"].mean()
# Out:
# np.float64(3078.334318134193)

# %% [markdown]
# ## 2) 데이터 요약하기

# %%
new_data.describe()
# Out:
#                 이용건수            운동량            탄소량       이동거리(M)  \
# count  619664.000000  619269.000000  619269.000000  6.196640e+05
# mean       36.207324    2171.806347      18.868742  8.161182e+04
# std        68.309988    4094.071706      34.935409  1.511538e+05
# min         1.000000       0.000000       0.000000  0.000000e+00
# 25%         4.000000     221.250000       2.010000  8.705685e+03
# 50%        12.000000     773.460000       6.950000  3.007392e+04
# 75%        39.000000    2391.900000      21.140000  9.141029e+04
# max      2454.000000  271725.720000    2652.600000  1.154394e+07
#
#              이용시간(분)     건당 이동거리(M)     건당 이용시간(분)
# count  619664.000000  619664.000000  619664.000000
# mean      741.158513    2701.308303      24.522191
# std      1343.878371    2035.965154      17.922810
# min         0.000000       0.000000       0.000000
# 25%        81.000000    1504.471840      13.866667
# 50%       274.000000    2138.456549      20.300000
# 75%       827.000000    3235.145285      30.000000
# max     95970.000000   74198.100000     863.000000

# %% [markdown]
# ## 3) 시각화

# %%
new_data.head()
# Out:
#      대여일자 대여소번호             대여소명 대여구분코드 성별 연령대코드  이용건수      운동량    탄소량  \
# 0  202407   102  102. 망원역 1번출구 앞    일일권  O   20대    67  4304.28  40.87
# 1  202407   102  102. 망원역 1번출구 앞    일일권  O   30대    64  4142.09  38.92
# 2  202407   102  102. 망원역 1번출구 앞    일일권  O   40대     2   265.91   2.11
# 3  202407   102  102. 망원역 1번출구 앞    일일권  O   50대     6   648.52   5.11
# 4  202407   102  102. 망원역 1번출구 앞    일일권  O   60대     1    35.37   0.31
#
#      이동거리(M)  이용시간(분)   건당 이동거리(M)  건당 이용시간(분)
# 0  176252.62     1895  2630.636119   28.283582
# 1  167774.15     1498  2621.471094   23.406250
# 2    9098.64       64  4549.320000   32.000000
# 3   22048.26      149  3674.710000   24.833333
# 4    1333.18        6  1333.180000    6.000000

# %% [markdown]
# ### 이전 코드 복습해보기

# %%
## 목표: "대여일자"열만 가지고 개수를 구해보자
## 판다스: .value_counts()를 통해 대여일자의 빈도표 출력해보기
## 시각화: sns.countplot을 이용하여 대여일자에 대한 막대그래프 그려보기

temp_data = new_data["대여일자"].value_counts().sort_index()
temp_data
# Out:
# 대여일자
# 202407    103502
# 202408    103316
# 202409    107191
# 202410    108791
# 202411    103677
# 202412     93187
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

plt.figure(figsize=(3,3))
temp_data.plot(kind="bar")
plt.title("이전 코드 복습해보기")
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.countplot(data=new_data, x="대여일자")
plt.title("이전 코드 복습해보기")
plt.show()

# %% [markdown]
# * 이 행은 대여소코드, 대여구분코드, 성별, 연령대코드별로 이용건수가 집계된 행이기 때문에 위의 시각화로는 의미를 도출하기가 힘들다

# %% [markdown]
# ### 건당 이동거리에 대한 히스토그램, 상자그림 그리기

# %%
# import matplotlib.pyplot as plt
# .hist(), .boxplot()
plt.figure(figsize=(3,3))
new_data["건당 이동거리(M)"].hist(bins=20)
plt.title("건당 이동거리에 대한 히스토그램")
plt.show()

# %%
plt.figure(figsize=(3,3))
plt.boxplot(new_data["건당 이동거리(M)"])
plt.title("건당 이동거리에 대한 상자그림")
plt.show()

# %% [markdown]
# ### 성별이 남자인 사람의 평균 이동거리, 평균 이용시간

# %% [markdown]
# ⭐ 고민 해볼 것
# * 이동거리, 이용시간은 어떻게 집계된 데이터일까?
# * 건당 이동거리, 건당 이용시간이 왜 필요할까?

# %% [markdown]
# #### 평균의 평균으로 계산한 값

# %%
## 목표: 데이터 요약
## 성별이 남자인 데이터 출력하기 data_m
## data_m에서 이동거리, 이용시간 추출한 후 .mean() 사용해보기

data_m = new_data[new_data["성별"]=="M"]
data_m[["건당 이동거리(M)", "건당 이용시간(분)"]].mean()
# Out:
# 건당 이동거리(M)    2668.111610
# 건당 이용시간(분)      23.170525
# dtype: float64

# %% [markdown]
# #### 정확한 계산식

# %%
# 남자 데이터의 이동거리 평균
print(data_m["이동거리(M)"].sum() / data_m["이용건수"].sum())
# Out:
# 2224.0466485714205

# %%
# 남자 데이터의 이용시간 평균
print(data_m["이용시간(분)"].sum() / data_m["이용건수"].sum())
# Out:
# 19.664125525743135

# %% [markdown]
# ### 성별로 평균 이동거리, 평균 이용시간

# %% [markdown]
# #### 평균의 평균값으로 계산

# %%
new_data.groupby("성별")["건당 이동거리(M)"].mean()
# Out:
# 성별
# F    2684.818708
# M    2668.111610
# O    2756.297323
# Name: 건당 이동거리(M), dtype: float64

# %% [markdown]
# #### 정확한 계산식

# %%
new_data.groupby("성별")["이동거리(M)"].sum()
# Out:
# 성별
# F    1.334666e+10
# M    2.358969e+10
# O    1.363556e+10
# Name: 이동거리(M), dtype: float64

# %%
new_data.groupby("성별")["이용건수"].sum()
# Out:
# 성별
# F     5862823
# M    10606653
# O     5966899
# Name: 이용건수, dtype: int64

# %%
new_data.groupby("성별")["이동거리(M)"].sum() / new_data.groupby("성별")["이용건수"].sum()
# Out:
# 성별
# F    2276.489991
# M    2224.046649
# O    2285.199998
# dtype: float64

# %% [markdown]
# ### 연령대별 이용건수

# %%
new_data.groupby("연령대코드")["이용건수"].sum()
# Out:
# 연령대코드
# 20대      6522094
# 30대      5787547
# 40대      3577567
# 50대      2482276
# 60대       833880
# 70대이상     135322
# ~10대     1515513
# 기타       1582176
# Name: 이용건수, dtype: int64

# %%
new_data.groupby("연령대코드")["이용건수"].agg(func=["sum"]).sort_index()
# 내가 정렬 커스텀하기
# Out:
#            sum
# 연령대코드
# 20대    6522094
# 30대    5787547
# 40대    3577567
# 50대    2482276
# 60대     833880
# 70대이상   135322
# ~10대   1515513
# 기타     1582176

# %%
new_data.groupby(["연령대코드", "성별"])["이용건수"].agg(func=["sum"]).reset_index()
# Out:
#     연령대코드 성별      sum
# 0     20대  F  1805094
# 1     20대  M  2552719
# 2     20대  O  2164281
# 3     30대  F  1505439
# 4     30대  M  2598205
# 5     30대  O  1683903
# 6     40대  F   934861
# 7     40대  M  1794545
# 8     40대  O   848161
# 9     50대  F   635389
# 10    50대  M  1287853
# 11    50대  O   559034
# 12    60대  F   154899
# 13    60대  M   513114
# 14    60대  O   165867
# 15  70대이상  F    25246
# 16  70대이상  M    88194
# 17  70대이상  O    21882
# 18   ~10대  F   383548
# 19   ~10대  M  1102213
# 20   ~10대  O    29752
# 21     기타  F   418347
# 22     기타  M   669810
# 23     기타  O   494019

# %% [markdown]
# ### 대여소별 이용건수

# %%
new_data.groupby("대여소명")["이용건수"].sum()
# Out:
# 대여소명
# 1001. 광진교 남단 사거리(천호공원 방면)     9762
# 1002. 해공공원(천호동)              15322
# 1003. 해공도서관앞                  7385
# 1004. 삼성광나루아파트 버스정류장         10468
# 1006. 롯데캐슬 115동앞              1540
#                              ...
# 992.북한산입구 정류장                  993
# 993.은평뉴타운 은뜨락아파트앞             2097
# 994.북한산생태공원입구(교통섬)            1639
# 995.은평다목적체육관                  2544
# 996.응암역2번출구 국민은행 앞           22174
# Name: 이용건수, Length: 2785, dtype: int64

# %% [markdown]
# ### 연령대별 이동거리, 이용시간의 평균

# %%
# groupby() 사용
new_data.groupby("연령대코드")[["건당 이동거리(M)", "건당 이용시간(분)"]].mean()
# Out:
#         건당 이동거리(M)  건당 이용시간(분)
# 연령대코드
# 20대    2451.222047   21.016007
# 30대    2586.120784   22.738673
# 40대    2878.267933   26.427358
# 50대    2944.130292   26.260852
# 60대    2802.546744   26.851123
# 70대이상  2555.291328   26.713537
# ~10대   2446.854491   22.019562
# 기타     2837.790135   26.163822

# %% [markdown]
# ## 4) 지도 시각화

# %% [markdown]
# ```
# uv add folium
# ```

# %%
new_data.head(1)
# Out:
#      대여일자 대여소번호             대여소명 대여구분코드 성별 연령대코드  이용건수      운동량    탄소량  \
# 0  202407   102  102. 망원역 1번출구 앞    일일권  O   20대    67  4304.28  40.87
#
#      이동거리(M)  이용시간(분)   건당 이동거리(M)  건당 이용시간(분)
# 0  176252.62     1895  2630.636119   28.283582

# %%
# 공공자전거 대여소 정보(api수집).csv
sub_data = pd.read_csv("data/공공자전거 대여소 정보(api수집).csv")
sub_data.head(1)
# Out:
#   STA_LOC RENT_ID  RENT_NO  RENT_NM    RENT_ID_NM  HOLD_NUM          STA_ADD1  \
# 0     마포구   ST-10      108  서교동 사거리  108. 서교동 사거리      12.0  서울특별시 마포구 양화로 93
#
#   STA_ADD2    STA_LAT    STA_LONG  START_INDEX  END_INDEX  RNUM
# 0      427  37.552746  126.918617            0          0     1

# %%
# RENT_NO, RENT_ID_NM, STA_LAT, STA_LONG 열만 가지고 오기
sub_data = sub_data[["RENT_NO", "RENT_ID_NM", "STA_LAT", "STA_LONG"]]
sub_data.head()
# Out:
#    RENT_NO         RENT_ID_NM    STA_LAT    STA_LONG
# 0      108       108. 서교동 사거리  37.552746  126.918617
# 1      503   503. 더샵스타시티 C동 앞  37.536667  127.073593
# 2      729   729. 서부식자재마트 건너편  37.510380  126.866798
# 3      731  731. 서울시 도로환경관리센터  37.529900  126.876541
# 4      732         732. 신월중학교  37.539551  126.828300

# %%
# [대여소번호, 대여소명, 위도, 경도]로 열 이름 바꾸기
sub_data.columns = ["대여소번호", "대여소명", "위도", "경도"]
sub_data.head()
# Out:
#    대여소번호               대여소명         위도          경도
# 0    108       108. 서교동 사거리  37.552746  126.918617
# 1    503   503. 더샵스타시티 C동 앞  37.536667  127.073593
# 2    729   729. 서부식자재마트 건너편  37.510380  126.866798
# 3    731  731. 서울시 도로환경관리센터  37.529900  126.876541
# 4    732         732. 신월중학교  37.539551  126.828300

# %%
new_data.head()
# Out:
#      대여일자 대여소번호             대여소명 대여구분코드 성별 연령대코드  이용건수      운동량    탄소량  \
# 0  202407   102  102. 망원역 1번출구 앞    일일권  O   20대    67  4304.28  40.87
# 1  202407   102  102. 망원역 1번출구 앞    일일권  O   30대    64  4142.09  38.92
# 2  202407   102  102. 망원역 1번출구 앞    일일권  O   40대     2   265.91   2.11
# 3  202407   102  102. 망원역 1번출구 앞    일일권  O   50대     6   648.52   5.11
# 4  202407   102  102. 망원역 1번출구 앞    일일권  O   60대     1    35.37   0.31
#
#      이동거리(M)  이용시간(분)   건당 이동거리(M)  건당 이용시간(분)
# 0  176252.62     1895  2630.636119   28.283582
# 1  167774.15     1498  2621.471094   23.406250
# 2    9098.64       64  4549.320000   32.000000
# 3   22048.26      149  3674.710000   24.833333
# 4    1333.18        6  1333.180000    6.000000

# %%
# new_data에서 대여소별로 이동거리(M), 이용시간(분), 이용건수의 합 구하기  summary_data
summary_data = new_data.groupby("대여소명")[["이동거리(M)", "이용시간(분)", "이용건수"]].sum()
summary_data.head()
# Out:
#                                이동거리(M)  이용시간(분)   이용건수
# 대여소명
# 1001. 광진교 남단 사거리(천호공원 방면)  22579951.13   212018   9762
# 1002. 해공공원(천호동)            37190390.67   349509  15322
# 1003. 해공도서관앞               14033033.55   155349   7385
# 1004. 삼성광나루아파트 버스정류장       32114486.56   309776  10468
# 1006. 롯데캐슬 115동앞            2869819.58    26311   1540

# %%
# summary_data에서 인덱스 리셋하기
summary_data = summary_data.reset_index()
summary_data.head()
# Out:
#                         대여소명      이동거리(M)  이용시간(분)   이용건수
# 0  1001. 광진교 남단 사거리(천호공원 방면)  22579951.13   212018   9762
# 1            1002. 해공공원(천호동)  37190390.67   349509  15322
# 2               1003. 해공도서관앞  14033033.55   155349   7385
# 3       1004. 삼성광나루아파트 버스정류장  32114486.56   309776  10468
# 4           1006. 롯데캐슬 115동앞   2869819.58    26311   1540

# %%
summary_data.shape
# Out:
# (2785, 4)

# %%
# 1003.해공도서관앞 대여소의 위도, 경도 찾기
sub_data.loc[sub_data["대여소명"]=="1003. 해공도서관앞","위도"].values[0]
# Out:
# np.float64(37.54395676)

# %%
summary_data["대여소명"].tolist()
# Out:
# ['1001. 광진교 남단 사거리(천호공원 방면)',
#  '1002. 해공공원(천호동)',
#  '1003. 해공도서관앞',
#  '1004. 삼성광나루아파트 버스정류장',
#  '1006. 롯데캐슬 115동앞',
#  '1007.암사동 선사유적지',
#  '1008. 암사역 3번출구(국민은행앞)',
#  '1009. 천호역4번출구(현대백화점)',
#  '1010. 강동세무서',
#  '1011. LIGA 아파트 앞',
#  '1012. 천호역효성해링턴타워 앞',
#  '1013. 강동구청역 1번 출입구',
#  '1015. 샛마을 근린공원',
#  '1016. 해뜨는 주유소옆 리엔파크 109동앞',
#  '1017. 둔촌고교입구 교차로(길동주민센터 방면)',
#  '1018. 둔촌 주공 GS 맞은편',
#  '1019. 다성이즈빌아파트(호원대 대각선 맞은편)',
#  '102. 망원역 1번출구 앞',
#  '1020. 강동경찰서',
#  '1021. 강일동 리슈빌 빌딩앞',
#  '1022. 길동 사거리(초소앞)',
#  '1023. 한국종합기술사옥 앞',
#  '1024.  강동구청 앞',
#  '1025. 상일초등학교',
#  '1027. 프라자 아파트 앞',
#  '1028. 포레스 주상복합 빌딩',
#  '1029. 성내어울터',
#  '103. 망원역 2번출구 앞',
#  '1030. 미호 플랜트 앞',
#  '1031. 올림픽로 836(아리수로)',
#  '1032. 선사고등학교',
#  '1033. 고덕동 아남아파트',
#  '1034. 고덕동 래미안 힐스테이트',
#  '1036. 고덕동 주양쇼핑',
#  '1037. 강일리버파크 6단지',
#  '1038. 강일 다솜 어린이 공원',
#  '1039. 고덕초등학교',
#  '104. 합정역 1번출구 앞',
#  '1041. 묘곡초등학교',
#  '1042. 강일리버파크 2~5단지',
#  '1044. 굽은다리역',
#  '1048. 둔촌어린이공원',
#  '1049. 강일리버파크 10단지',
#  '105. 합정역 5번출구 앞',
#  '1050.  둔촌역 3번 출입구',
#  '1051. 강일중,선사고 버스정류장(신암중학교 방면)',
#  '1053. 동명근린공원 진입로 (아리수로)',
#  '1054. 말우물 어린이 공원',
#  '1056. 강일리버파크 7~11단지',
#  '1057. 능골근린공원',
#  '1058. 고덕숲 아이파크 1',
#  '1059. 래미안 강동팰리스(102동)',
#  '106. 합정역 7번출구 앞',
#  '1060. 천일초교 사거리',
#  '1061. 천호초교 입구 사거리(일주빌딩)',
#  '1062. 고덕숲 아이파크 2',
#  '1063.강동롯데캐슬퍼스트 아파트(관리동)',
#  '1064.중앙보훈병원역 1번출구',
#  '1065.보훈병원 후문옆(더 원커피)',
#  '1066.생태공원앞 교차로(조명탑)',
#  '1067.한영중고앞사거리',
#  '1068.명일파출소',
#  '107. 신한은행 서교동지점',
#  '1070.(시립)고덕평생학습관',
#  '1072.고덕역 5번출구',
#  '1073. SSTS 몰 앞',
#  '1074.대명초교입구 사거리',
#  '1075.천동초교 삼거리',
#  '1076. 천동초교입구사거리 버스정류장(십자성마을 방면)',
#  '1077.강동역 1번출구 앞',
#  '1078.둔촌사거리',
#  '1079.강일동입구교차로',
#  '108. 서교동 사거리',
#  '1080.엘웨딩',
#  '1081.트레빌빌딩',
#  '1082.중앙보훈병원역3번출구',
#  '1083.광문고교사거리(아이파크)',
#  '1084. 윤선생빌딩(JYP사옥)',
#  '1085.래미안 솔베뉴(고덕로)',
#  '1086.래미안 솔베뉴(구천면로)',
#  '1088.풍납사거리(강동)',
#  '1089.고덕 래미안힐스테이트(201동)',
#  '1090.상일동역 2번출구 앞',
#  '1101. 상사마을 버스정류장(아라대교방면)',
#  '1102. 방화사거리 마을버스 버스정류장',
#  '1103. 방화역 4번출구앞',
#  '1105. 방화근린공원',
#  '1106. 신방화사거리',
#  '1108. 공항시장역 2번출구 뒤',
#  '1109. 공항시장역 4번출구',
#  '111. 상수역 2번출구 앞',
#  '1110. 공항중학교앞',
#  '1111. 마곡엠밸리6_7단지 마곡중학교',
#  '1112. 마곡엠밸리4단지 정문',
#  '1113. 서남환경공원 버스정류장',
#  '1117. 등촌5단지아파트 버스정류장',
#  '1118. 증미역 3번출구뒤(등촌두산위브센티움오피스텔)',
#  '1119. 염창동 한마음아파트 앞',
#  '1120. 대림경동아파트앞',
#  '1121. 가양레포츠센터 앞',
#  '1122. 황금내근린공원',
#  '1124. 발산역 6번 출구 뒤',
#  '1125. 명덕고교입구(영종빌딩)',
#  '1126. 우장산역 1번출구옆(우장산아이파크105동앞)',
#  '1127. 화곡역 버스정류장',
#  '1128. 화곡역 6번출구',
#  '1129. 화곡역 1번 출구 앞',
#  '113. 홍대입구역 2번출구 앞',
#  '1130. 화곡본동시장 버스정류장',
#  '1132. 등촌역 7번출구',
#  '1135. 강서구의회',
#  '1136. 등촌2파출소',
#  '1137. 등촌2동주민센터',
#  '1139. 용문사 버스정류장',
#  '114. 홍대입구역 8번출구 앞',
#  '1140. 목동사거리 버스정류장',
#  '1141. 곰달래 문화복지센터 A',
#  '1145. 곰달래 문화복지센터 B',
#  '1148. 볏골공원',
#  '1149. 신방화역환승주차장',
#  '115. 마스타 빌딩 앞',
#  '1150. 송정역 1번출구',
#  '1151. 마곡역1번출구',
#  '1152. 마곡역교차로',
#  '1153. 발산역 1번, 9번 인근 대여소',
#  '1155. 기쁜우리복지관',
#  '1157. 강서구청',
#  '1158. 가양역 8번출구',
#  '1159. 서서울모터리움 앞',
#  '1160. 양천향교역 7번출구앞',
#  '1161. 강서면허시험장 앞',
#  '1162. 공항초등학교건너편',
#  '1163. 방화동강서기동대앞',
#  '1165. 마곡중학교 후문',
#  '1166. 강서구립등빛도서관',
#  '1167. 마곡수명산파크3단지 교차로',
#  '1168. 마곡엠밸리10단지 앞',
#  '1169. 염창역 1번 출구',
#  '117. 홍은사거리',
#  '1170. 강서구보건소',
#  '1171. 염창동 새마을금고 건너편',
#  '1172. 가양3동 주민센터',
#  '1173. 강서구청사거리(SH타워)',
#  '1174. 강서구청사거리(부민병원)',
#  '1175. 대한항공 인력개발센터',
#  '1177. 수명중?고교',
#  '1178. 개화산역 2번 출구',
#  '118. 광흥창역 2번출구 앞',
#  '1180. 마곡엠밸리 15단지(1502동) 건너편',
#  '1181. 농수산식품공사 (강서지사)',
#  '1182. KBS 스포츠월드',
#  '1183. 강서대학교',
#  '1184. 마곡13단지',
#  '1185. 등촌9단지',
#  '1186. 송정중학교',
#  '1187. 강서수산물도매시장',
#  '1188. 롯데중앙연구소',
#  '119. 서강나루 공원',
#  '1190. 마곡역 교차로(2번출구)',
#  '1191. 마곡역 버스정류장(마곡나루역1번출구, 웰튼병원 방면)',
#  '1192. 마곡수명산파크 209동 건너편',
#  '1193. 마곡센트럴타워 1차',
#  '1195. 코오롱One&Only타워',
#  '1196. 서울식물원(문화센터) 건너편',
#  '1197. 엠펠리체 호텔 건너편',
#  '1198. LG 사이언스파크',
#  '1199. 우장산역 3번출구',
#  '120. 신수동 사거리',
#  '1200. 개화광역환승센터',
#  '1201. 가락시장역 3번 출구',
#  '1203. 밀리아나2빌딩 앞',
#  '1204. 거여역 3번출구',
#  '1205. 종합운동장역 4번출구',
#  '1206. 9호선종합운동장역 9번출구',
#  '1207. 마천중앙시장',
#  '1208. 풍납현대아파트쉼터',
#  '1209. 잠실나루역 (2번 출구 쪽)',
#  '121. 마포소방서 앞',
#  '1210. 롯데월드타워(잠실역2번출구 쪽)',
#  '1212. 송파역 2번 출구앞',
#  '1213. 백토공원 앞',
#  '1214. 오금역 7번 출구 인근',
#  '1215. 올림픽공원역 1번출구 앞',
#  '1217. 송파파인타운 7단지',
#  '1218. 방이역 4번출구',
#  '122. 신성기사식당 앞',
#  '1220. 잠실근린공원',
#  '1221. 삼전역 4번출구',
#  '1222. 잠실새내역 5번 출구 뒤',
#  '1224. 아시아지하보도 2번 출구',
#  '1226. 잠실4동 주민센터 옆',
#  '1227. 거여역 8번출구 뒤',
#  '1228. 마천사거리 ',
#  '1229. 송파체육문화회관 앞',
#  '123. 문화촌 공원',
#  '1230. 송파중학교 정문',
#  '1231. 잠실역 6번출구',
#  '1232. 잠실주공 521동 건너편',
#  '1233. 잠실3거리(갤러리아팰리스)',
#  '1235. 잠실트리지움310동 옆',
#  '1239. 문정 법조단지3',
#  '124. 서강대 정문 건너편',
#  '1240. 문정 법조단지4',
#  '1241. 문정 법조단지5',
#  '1242. 문정 법조단지6',
#  '1243. 문정 법조단지7',
#  '1244. 문정 법조단지8',
#  '1245. 문정 법조단지9',
#  '1246. 문정 법조단지10',
#  '1247. 문정 법조단지11',
#  '1248. 방이초등학교',
#  '1250.문정2동 주민센터',
#  '1251. 석촌역 2번출구',
#  '1253. 오금역 3번 출구 뒤',
#  '1256. 문정현대아파트 교차로',
#  '1257. 가락시장역 사거리',
#  '1258. 가락미륭아파트 앞',
#  '1259. 방이역 1번출구',
#  '126. 서강대 후문 옆',
#  '1260. 방이동 한양3차아파트 옆',
#  '1262. 송파여성문화회관 앞',
#  '1263. 장지공영차고지',
#  '1264. 천호역 10번 출구 앞',
#  '1265. 문정동 근린공원',
#  '1266. 문정동 글샘 공원',
#  '1267. 올림픽공원 남2문 앞',
#  '1268. 몽촌토성역 1번출구 옆',
#  '1269. 리센츠아파트 ',
#  '127. 현대벤처빌 앞',
#  '1271. 송파도서관',
#  '1274. 영파여고 앞',
#  '1275. 거여초등학교 옆',
#  '1277. 성내7교',
#  '1278. 송파구청 교차로',
#  '1279. 마천금호어울림 1차아파트 건너편',
#  '128. 신촌역(2호선) 1번출구 옆',
#  '1280. 송파파크데일 2단지입구 앞 주차장',
#  '1282. 송파소방서 맞은편(성내4교)',
#  '1283. 오금공원 사거리',
#  '1285. 위례별 유치원 뒤',
#  '1286. 위례중앙푸르지오 1단지 앞',
#  '1287. 위례아이파크 101동 맞은편',
#  '1288. 문정중교 사거리',
#  '1289. 풍납토성 서성벽터B',
#  '129. 신촌역(2호선) 6번출구 옆',
#  '1290. 위례송파꿈에그린아파트24단지 앞 성벽 다리 밑',
#  '1291. 서울체육고등학교 앞',
#  '1293. 석촌호수 서호 사거리',
#  '1295. 잠실역 8번출구',
#  '1296. 석촌호수교차로 (송파나루근린공원 앞)',
#  '1297. 석촌호수교차로(동호 팔각정 앞)',
#  '1299. 송파소방서 (방이119안전센터)',
#  '130. 신촌역(2호선) 7번출구 앞',
#  '1300. 오륜사거리',
#  '1302. 한성대입구역6번출구 뒤',
#  '1303. 돈암초교 입구',
#  '1304. 만해공원',
#  '1305. 성북구청',
#  '1306. 한성대입구역2번출구',
#  '1308. 안암로터리 버스정류장 앞',
#  '131. 증산2교',
#  '1314. 정릉꿈에그린1단지 201동 앞',
#  '1315. 고려사대부속중고 정문',
#  '1316. 고려사대부속중고 건너편 ',
#  '1318. 길음역 3번출구 뒤',
#  '1319. 종암박스파크',
#  '1321. 국민은행 종암동지점 앞',
#  '1322. 래미안라센트아파트 103동 앞',
#  '1325. 상월곡역 4번출구',
#  '1326. 상월곡역 1번출구',
#  '1327. 상월곡역 3번출구',
#  '1328. 월곡역 3번출구',
#  '133. 해담는다리',
#  '1332. 석계역 5번출구 건너편',
#  '1333. 석관초등학교 앞',
#  '1334. 석관동주민센터 앞',
#  '1336. 성북3교 위',
#  '1337. 돈암성당 옆',
#  '1338. 용문2교 옆',
#  '1339. 삼성전자서비스 성북센터',
#  '134. 연세로 명물길',
#  '1340. 광운초등학교 앞',
#  '1342. 성북쉼터 앞',
#  '1343. 한성대7번출구 앞',
#  '1344. 아리랑시네센터 앞',
#  '1346. 길음8골어린이공원 옆',
#  '1347. 길음래미안아파트817동 상가 앞',
#  '1348. 성북제일새마을금고 본점 앞',
#  '1349. 월계2교 버스정류장 앞',
#  '135. 명물길 원형무대 앞',
#  '1351. 안암2교 옆',
#  '1352. e 편한세상 보문아파트 내',
#  '1353. 금호어울림센터힐 내',
#  '1354. 고려대학교 2번출구',
#  '1355. 보문2교',
#  '1357. 북한산보국문역',
#  '1358. 정릉도서관 앞',
#  '1360. 정릉역',
#  '1361. 홍익중고 입구',
#  '1362. 보문역6번출구 앞',
#  '1363. 보문4교 인근',
#  '1364. 성북동 치안센터 앞',
#  '1365. 선잠단지 앞',
#  '1366. 일신초등학교 옆',
#  '1367. 길음문화복합미디어센터',
#  '1368. 성신여대입구 교차로',
#  '137. 신촌기차역입구 교차로',
#  '1370. 복자사랑 피정의 집',
#  '1372. KEB은행 고대점',
#  '1373. 성북구보건소 건너편',
#  '1375. 생명의 전화 종합복지관 앞 교차로',
#  '1376. 한국과학기술연구원 중문',
#  '1377. 한국과학기술연구원 북문',
#  '1379.길음뉴타운푸르지오아파트 3단지',
#  '138. 신촌동 제1공영주차장 앞',
#  '1380.월곡역 5번출구 앞',
#  '1381.석계역 4번출구 뒤',
#  '1382.래미안월곡아파트 입구',
#  '1384.성신여대입구역 5번출구',
#  '1385.성신여대입구역 3번출구 앞',
#  '1386.동선고가차도 초입',
#  '1388. 돈암초교입구 버스정류장(한성대입구역 방면)',
#  '139. 연세대 정문 건너편',
#  '1390.석관래미안아트리치',
#  '1391.성북청소년센터',
#  '1392.돈암삼성풍림아파트',
#  '1393.돈암육교 하단',
#  '1394.길음뉴타운 래미안9단지',
#  '1395.래미안장위포레카운티(102동)',
#  '1396.래미안장위퍼스트하이(513동)',
#  '140. 이화여대 후문',
#  '1401. 극동늘푸른아파트',
#  '1402. 금란주차장 앞',
#  '1403. 중화빌딩 앞 (동부시장)',
#  '1404. 동일로 지하차도',
#  '1405. 망우역 1번출구',
#  '1407. 먹골역 1번출구 뒤',
#  '1408. 먹골역 6번출구 앞',
#  '141. 연대 대운동장 옆',
#  '1410. 면목 대원칸타빌아파트',
#  '1411. 상봉시장앞 교차로 한성빌딩 앞',
#  '1414. 사가정역 2번출구',
#  '1416. 상봉역 3번출구',
#  '1418. 새솔초등학교',
#  '142. 아현역 4번출구 앞',
#  '1420. 신내어울공원 앞',
#  '1421. 신내역 4번출구',
#  '1422. 신내우디안아파트 1단지',
#  '1424. 양원역 2번출구',
#  '1425. 신성미소지움아파트',
#  '1426. 면목도시개발아파트 1동 앞',
#  '1427. 용마산역 1번출구',
#  '1428. 원묵고등학교',
#  '1429. 장안중학교',
#  '143. 공덕역 2번출구',
#  '1430. 중랑구청',
#  '1431. 중랑구청 사거리',
#  '1433. 중화역 2번출구',
#  '1435. 능산삼거리',
#  '1436. 동원베네스트 건물 앞',
#  '1437. 늘푸른공원 앞',
#  '1438. 홈플러스 신내점 앞',
#  '144. 공덕역 8번출구',
#  '1440. 면목2동 사거리',
#  '1441. 신내능말공원',
#  '1442. 중랑구청 중화동 별관 앞',
#  '1444. 면목4치안센터',
#  '1445. 용마지구대 A',
#  '1446. 중랑전화국 교차로',
#  '1447. 면목역 3번출구',
#  '1448. 코스트코 상봉점',
#  '1449. 상봉역 1번출구',
#  '145. 공덕역 5번출구',
#  '1450. 화랑대역 7번출구',
#  '1451. 중랑세무서',
#  '1452. 겸재교 진입부',
#  '1453. 중랑캠핑숲',
#  '1454. 한국전력공사(동대문 중랑지사)',
#  '1455. 상봉역 2번 출구',
#  '1456. 상아빌딩(우림시장 교차로)',
#  '1457. 동원사거리',
#  '1458. 상봉터미널2',
#  '1459. 용마한신아파트사거리',
#  '146. 마포역 2번출구 뒤',
#  '1461.동양엔파트 앞',
#  '1462.동부시장 북문 앞',
#  '1463.중랑구민회관',
#  '1464.중화역 4번출구',
#  '1466.두산대림아파트 삼거리',
#  '1467.sk신내 주유소앞(용마산로)',
#  '1468.먹골역 7번 출구',
#  '1469.먹골역 4번출구',
#  '147. 마포역 4번출구 뒤',
#  '1470.중화동 우리은행 앞',
#  '1471.동양쇼핑 정류소 앞',
#  '1472.영성빌딩(PAT)',
#  '1473.중랑역 1번 출구(중화문화복지센터)',
#  '1474.서울중랑우체국',
#  '1477.면목삼익아파트 앞',
#  '1478.홈플러스 상봉점 앞',
#  '1479.면목 홈플러스 2 ',
#  '148. 용강동 주민센터 앞',
#  '1480. 용마지구대 B',
#  '150. 서강대역 2번출구 앞',
#  '1501. 미아역 3번,4번 출구 사이',
#  '1503. 강북구청사거리(수유역 8번출구)',
#  '1504. 삼양시장오거리',
#  '1506. 강북문화예술회관',
#  '1509. 서울북부수도사업소',
#  '1510. 번동주공5단지 관리사무소 앞',
#  '1511. 번동 금호어울림아파트102동앞',
#  '1512. 강북중학교 앞',
#  '1513. 강북구청 뒷편',
#  '1514. 강북구청 사거리 버스정류소 앞',
#  '1515. 송천동 주민센터',
#  '1516. 우이동길마을마당',
#  '1518. 수유2동은행빌딩 앞',
#  '1519. 장미원시장 건너편',
#  '1520. 수유중앙시장',
#  '1525. 미아동 복합청사',
#  '1526. 강북종합시장 앞',
#  '1527. 미아역 1번 출구 뒤',
#  '1528. 삼각산동 주민센터',
#  '1529. 미아동 한국전력공사',
#  '153. 성산2교 사거리',
#  '1530. 광산사거리',
#  '1531. 미아사거리 1번 출구',
#  '1532. 번3동 주민센터 교차로',
#  '1533. 번동 주공3, 4단지 교차로',
#  '1535. 효성인텔리안 앞',
#  '1536. 번동 두산위브 101동 옆',
#  '1537. 북한산 우이역',
#  '1538. 솔밭공원역',
#  '1539. 4.19민주묘지역',
#  '154. 마포구청역 ',
#  '1540. 가오리역',
#  '1541. 삼양역',
#  '1542. 삼양사거리역',
#  '1543. 수유1동 주민센터',
#  '1546. 송천동우체국',
#  '1547. 꿈의숲 롯데캐슬',
#  '1548. 북서울 꿈의숲 서문',
#  '155. 가좌역1 번출구 앞',
#  '1550.삼각산아이원아파트(105동 옆)',
#  '1551.4.19탑 앞',
#  '1552. 강북구청사거리',
#  '1553.서울북부고용노동지청',
#  '1554.번동사거리',
#  '1557.신창교',
#  '1558.강북문화정보도서관',
#  '156. 서울서부지방법원 앞',
#  '1560. 도봉세무서 앞',
#  '1564.4.19민주묘지역 1번출구',
#  '1565.수유사거리',
#  '1568.4.19민주묘지 입구사거리',
#  '1569.수유역2번출구',
#  '157. 애오개역 4번출구 앞',
#  '1571.북서울 꿈의 숲 입구',
#  '1572. 우이동 먹거리마을',
#  '1573.현대성우아파트 옆',
#  '1574.송중초등학교 옆',
#  '159. 이대역 4번 출구',
#  '160. 북아현동 가구거리',
#  '1601. 석계역 문화광장 내 자전거 보관소',
#  '1602. 광운대역 앞',
#  '1605. 헬스케어',
#  '1606. 태릉입구역 3번출구 ',
#  '1608. 공릉역 1번 출구 앞',
#  '161. 무악재역1번 출구',
#  '1610. 화랑대역 2번출구 앞',
#  '1611. 과기대 입구(우)',
#  '1616. 하계2동 공항버스정류장 옆',
#  '1617. 하계동 중평어린이공원 앞',
#  '1619. 중계동 하나프라자빌딩 앞(중1-1)',
#  '162. 봉원고가차도 밑',
#  '1620. 중계동 노원구민체육센터 옆(중1-2)',
#  '1625. 상계역 3번출구',
#  '1627. 수락산역 4번출구',
#  '1628. 노일초등학교 앞',
#  '163. 명지전문대학교 정문 앞',
#  '1630. 수연빌딩 앞',
#  '1634. 당고개공원 대여소',
#  '1635. 상계3,4동 주민센터 대여소',
#  '1636. 상계주공2단지 버스정류장 옆',
#  '1637. KT 전화국 버스정류장 옆',
#  '1639. 희성오피앙',
#  '164. 북가좌1동 주민센터 ',
#  '1640. 한내근린공원 북측',
#  '1641. 한내근린공원 남측',
#  '1642. 서울여대 남문',
#  '1643. 태릉입구역 8번출구',
#  '1646. 삼육대 입구',
#  '165. 중앙근린공원',
#  '1650. 중계근린공원내',
#  '1651. 상계동 우방유쉘아파트 앞',
#  '1652. 파르코 앞',
#  '1653. 노원역1번출구',
#  '1654. 당고개입구 오거리',
#  '1655. 공릉1단지아파트',
#  '1656. 중앙하이츠 아파트 입구',
#  '1657. 노원구청 ',
#  '1659. 중계동 을지중학교',
#  '166. 가재울 초등학교',
#  '1660. 서울시립과학관',
#  '1661. 당현천근린공원',
#  '1662. 노원역7번출구',
#  '1663. 동해문화예술관앞',
#  '1664. 노해근린공원내',
#  '1665. 양지근린공원앞',
#  '1666. 노원소방서인근',
#  '1667. 중계중학교',
#  '1668. 중계역 6번출구',
#  '1669. 중계역 3번출구',
#  '167. 연가초등학교 옆',
#  '1670. 노원경찰서교차로',
#  '1671. 인덕대학교',
#  '1672. 상계동수락리버시티',
#  '1674. 서울북부고용센터앞',
#  '1675. 월계문화체육센터',
#  '1677. 육군사관학교  앞',
#  '1678. 성서대학교 밀알관',
#  '1679. 삼육대 도서관',
#  '1680. 삼육대 제3과학관',
#  '1681. 현대6차 아파트',
#  '1682. 중계종합사회복지관 교차로',
#  '1683. 노원문화예술회관',
#  '1684. 태릉입구역 5번출구',
#  '1685. 불암고등학교 앞 횡단보도',
#  '1686. 상계주공10단지 종합상가 앞',
#  '1688. 마들역 7번출구',
#  '1689. 마들역 3번출구',
#  '169. 북가좌 삼거리',
#  '1690. 도봉운전면허시험장 버스정류장 옆',
#  '1691. 노원정보도서관',
#  '1692. 온곡초교 교차로',
#  '1693. 원자력 병원',
#  '1696.수락리버시티4단지',
#  '1697.상계주공2단지 219동',
#  '170. DMC파크뷰자이아파트 302동 앞',
#  '1702. 녹천역 1번출구 앞',
#  '1703. 도봉산광역환승센터앞 ',
#  '1705. 도봉구청 정문앞',
#  '1706. 방학동우체국 건너편',
#  '1707. 도봉구민회관',
#  '1708. 도봉보건소사거리',
#  '1709. 쌍문역4번출구 주변',
#  '171. 임광빌딩 앞',
#  '1713. 쌍문동 이안아파트 앞',
#  '1714. 도봉문화정보도서관 삼거리',
#  '1715. 서울특별시교육청도봉도서관',
#  '1716. 창동역 1번출구 건너편',
#  '1719. 신도봉사거리 버스정류장',
#  '1720. 도봉구청 옆(중랑천변)',
#  '1721. 창동역 2번출구 ',
#  '1722. 창동청소년수련관',
#  '1723. 방학동학마을도서관',
#  '1725. 창1동주민센터',
#  '1726. 삼익세라믹아파트교차로',
#  '1727. 서울도봉초등학교인근',
#  '1728. 서울북부지방법원',
#  '1729. 도봉한신아파트 버스정류장',
#  '173. 서대문역 8번출구 앞',
#  '1730. 도봉산역 교차로 앞',
#  '1731. 도봉고등학교 맞은편',
#  '1732. 방학역사거리',
#  '1733. 방학사거리 (봄마당 앞)',
#  '1734. 쌍문현대1차아파트 108동 앞',
#  '1735. 도봉역 1,2번 출구사이 건너편',
#  '1736. 버스정류장 앞',
#  '1737. 신창시장',
#  '1738. 창동주공17단지 상가앞',
#  '1741. 제일강산수산입구',
#  '1742. 북한산 코오롱 하늘채',
#  '1743.창동19단지아파트 관리사무소앞',
#  '1744.도봉소방서 옆',
#  '1749. ESA아파트 상가 앞',
#  '175. 홍연2교옆',
#  '1750. 창포원 남쪽 입구',
#  '1751. 창원초등학교 교차로',
#  '1752. 창동 주공 4단지 입구 옆',
#  '1754. 창동시장입구 사거리',
#  '1756.서울북부광역등기국',
#  '1757.솔밭공원역 1번출구 앞',
#  '1758.솔밭공원역 1번출구 주변',
#  '1759.서울북부지방법원 앞',
#  '176. 명지대학교 도서관',
#  '1761.방학중학교 앞',
#  '1762.북한산 한신휴플러스APT앞',
#  '1765.쌍문역 1번출구 주변',
#  '1767.방학초등학교 앞',
#  '1768.신동아타워 버스정류소',
#  '177. 북가좌 초등학교',
#  '1770.도봉한신아파트 주변',
#  '1771.성원APT버스정류소',
#  '1772.시립도봉노인복지관 버스정류소',
#  '1774.정의여중고 버스정류소',
#  '1775.신원리베르텔 앞',
#  '178. 증산3교 앞',
#  '179. 가좌역 4번출구 앞',
#  '180. 충정로역 7번출구 아래',
#  '1804. 독산역 2번출구 자전거주차장',
#  '1805. 서울디지털운동장 앞',
#  '1806. 에이스하이엔드타워9차 앞',
#  '1808. 에이스하이엔드타워8차 앞',
#  '1809. LG전자 별관동(호서대 벤처타워 맞은편)',
#  '181. 망원초록길 입구',
#  '1812. 갑을그레이트밸리 앞',
#  '1814. 두산위브아파트 옆 상가건물 앞',
#  '1819. 금천구청 앞 자전거거치대',
#  '182. 망원2빗물펌프장 앞',
#  '1820. 신한은행 시흥대로금융센터지점',
#  '1821. 홈플러스 시흥점 맞은편 다비치안경 앞',
#  '1822. 서울 시흥동우체국 앞',
#  '1823. 상신정비공업 앞',
#  '1824. 독산근린공원 입구',
#  '1825. 한신아파트 앞 육교 아래',
#  '1826. 한신코아 앞',
#  '1827. 독산보도육교 앞 자전거 보관소',
#  '1828. 한양수자인아파트 앞',
#  '1829. 홈플러스 금천점 앞',
#  '183. 하늘채코오롱아파트 건너편',
#  '1830. 빅마켓 금천점 앞',
#  '1831. 한국전력 구로금천지사 앞',
#  '1833. 독산역 1번출구 A',
#  '1834. 월드메르디앙 벤처센터 2차',
#  '1835. STX V타워',
#  '1836. 금천구립 독산도서관',
#  '1839. 수출의 다리 아래',
#  '184. 7번가피자 서교망원점',
#  '1840. 솔브레인이엔지 뒤편',
#  '1841. 가산동 주민센터',
#  '1842. 한울중학교',
#  '1843. 독산고등학교',
#  '1845. 롯데캐슬골드파크1차 서문',
#  '1846. 롯데캐슬골드파크1차 동문',
#  '1847. 독산주공 14단지 버스정류소',
#  '1848. 벽산 디지털밸리 5차',
#  '1849. 대륭포스트타워5차',
#  '185. 마포 신수공원 앞',
#  '1850. 코오롱테크노밸리',
#  '1851. 가산디지털단지 9번출구 인근',
#  '1853. 서울디자인직업전문학교 앞',
#  '1854. 가산아네스트 오피스텔 앞',
#  '1855. 성지아파트 옆 도로변',
#  '1856. 모두의학교',
#  '1857. 주공14단지',
#  '1858. 500번,507번 버스 종점 앞',
#  '1859. 대륭테크노타운 18차',
#  '186. 월드컵공원',
#  '1861.IBK기업은행 석수역 지점 앞',
#  '1862.스타즈호텔독산 빌딩 앞',
#  '1863.위너스 스포츠클럽 골프연습장옆',
#  '1864.산호시티빌 옆',
#  '1865.금천구청앞(M빌딩)',
#  '1866.서울안천초등학교 옆',
#  '1867.대륭포스트타워6차 앞',
#  '1868.우리은행 시흥남자동화점 앞',
#  '1869.롯데캐슬골드파크3차 301동 앞',
#  '1870.독산3동주민센터 앞',
#  '188. 홍은동 정원여중 입구',
#  '1901. 신도림동주민센터 앞',
#  '1904. 도림천역 1번 출구 앞',
#  '1906. 신도림역 1번 출구 앞',
#  '1907. 구일우성(아) 육교 밑',
#  '1908. 해원리바파크 육교 밑',
#  '191. 서우빌딩',
#  '1910. 낙원교회 맞은편',
#  '1911. 구로디지털단지역 앞',
#  '1912. 한신휴아파트 앞',
#  '1914. 대림역4번출구',
#  '1916. 구로중학교앞',
#  '192. 연서어린이공원',
#  '1920. 서울미래초등학교 사거리',
#  '1924. 삼부르네상스파크빌',
#  '1925. 동양미래대학교 정문 옆',
#  '1928. 고척스카이돔구장 광장',
#  '1929. 고척근린공원 고척도서관 앞',
#  '1930. 개봉지구대 개봉치안센터',
#  '1931. 개봉역2번출구 A',
#  '1933. 개봉푸르지오아파트 상가',
#  '1936. 개봉역 1번 출구 자전거보관서쪽',
#  '1937. 한진아파트 입구',
#  '194. 증산교 앞',
#  '1941. 오류동역 2번출구',
#  '1943. 온수역 북측',
#  '1946. 구로역 광장',
#  '195. 모래내고가차도 ',
#  '1951. 천왕이펜하우스 4단지 후문',
#  '1952. 천왕연지타운2단지 앞',
#  '1953. 천왕역 4번출구 뒤',
#  '1955. 디지털입구 교차로',
#  '1956. 동아1차APT105동 버스정류장(신도림중학교 방면)',
#  '1957. 구일고등학교 정문 ',
#  '1958. 강서수도사업소민원센터',
#  '1959. 구로구의회 앞',
#  '196. 연희교차로 인근',
#  '1960. 구로거리공원 동측(신도림역 방면)',
#  '1961. 신도림테크노근린공원',
#  '1962. 가리봉동주민센터',
#  '1964. 원메디타운 앞',
#  '1965. 삼환로즈빌아파트 105동 옆',
#  '1966. 한마을아파트 정문상가',
#  '1967. 참새공원(백곡경노당)',
#  '1968. 동인오피스텔 건너편 소공원',
#  '1969. 궁동생태공원',
#  '1971. 오정초교 앞 보도육교',
#  '1973. 오리로와 서해안도로 교차로 앞',
#  '1974. 신도림2차e편한세상아파트 203동 앞',
#  '1975. 대림역 1번 출입구 밑',
#  '1976. 남구로역 5번 출입구 앞',
#  '1977. 천왕역 1번 출입구 앞',
#  '1979. 구로1동우체국 앞',
#  '198. 충정2교',
#  '1981. 천왕지구삼거리 앞',
#  '1983. 구로동롯데아파트',
#  '1984. 구로구청',
#  '1985. 구로도서관',
#  '1986. 태평양물산',
#  '1987. 개봉아이파크아파트 앞',
#  '1988. 고척LIGA아파트 앞',
#  '199. 서울 월드컵 경기장',
#  '1991. 오류동역 맞은편',
#  '1992. 구로구배드민턴실내체육관 앞',
#  '1993. 금강수목원아파트 앞',
#  '1994. 삼성전자 물류센터 앞',
#  '1996. 구일역 1번 출입구 앞',
#  '1998. 고척교 교차로',
#  '1999. 수궁동 성당 주변',
#  '200. 국회의원회관',
#  '2000. 신도림4차 e편한세상 아파트 1109동 앞',
#  '2002. 노들역 1번출구',
#  '2003. 사육신공원앞',
#  '2007. 유한양행앞',
#  '2008. 노량진근린공원 대방공원',
#  '2009. 보라매역 8번출구',
#  '201. 진미파라곤 앞',
#  '2012. 대림사거리(동작상떼빌아파트)',
#  '2013. 장승배기역 5번출구',
#  '2015. 신대방삼거리역 6번출구쪽',
#  '2016. 신대방삼거리역 3번출구쪽',
#  '202. 국민일보 앞',
#  '2020. 장승배기역2번출구뒷편쪽',
#  '2024. 상도역 1번출구',
#  '2025. 흑석역 1번출구',
#  '2026. 흑석역 4번출구',
#  '2027. 중앙대학교 정문 1',
#  '203. 국회의사당역 3번출구 옆',
#  '2032. 이수역 11번출구쪽',
#  '2033. 사당동 아르테스 웨딩앞',
#  '2034. 사당역 7번출구쪽',
#  '2036. 정금마을 마을버스정류장',
#  '2037. 동작역 5번출구 동작주차공원',
#  '2038. 동작역 7번출구',
#  '204. 국회의사당역 5번출구 옆',
#  '2040. 비계 버스정류소',
#  '2041. 사당중학교 버스정류소',
#  '2048. 삼일초등학교 인근',
#  '205. 산업은행 앞',
#  '2050. 노량진역 5번출구',
#  '2054. 삼익아파트',
#  '2056. 동작구민 체육센터',
#  '2057. 상도 아이파크 아파트',
#  '2058. 동작경찰서',
#  '2059. 보라매공원 정문',
#  '206. KBS 앞',
#  '2060. 남성역3번출구 뒤',
#  '2061. 한강 현대아파트 건너편',
#  '2062. 사당새마을금고',
#  '2064. 흑석한강푸르지오 106동앞',
#  '2065. 서울시여성가족재단',
#  '2066. 양문교회 앞',
#  '2067. 보라매역?동작세무서 버스정류장(강남중학교방면)',
#  '2068. 총신대 앞(육교)',
#  '2069. 숭실대 입구역3번 출구 앞',
#  '207. 여의나루역 1번출구 앞',
#  '2070. 노량진역 2번 출구 앞',
#  '2071. 대림아파트 후문 상가 옆',
#  '2077.노들역 3번출구',
#  '2078.흑석 아크로리버하임(103동)',
#  '2079.중앙대학교 중앙광장',
#  '2080. 대방지하보도(대방동경남아너스빌아파트)',
#  '2082.7호선 이수역7번출구',
#  '2083.흑석롯데캐슬에듀포레(107동)',
#  '2084.e편한세상 상도노빌리티 앞',
#  '2085.강남중학교 앞',
#  '2086.삼일수영장 앞',
#  '2088.상도중앙하이츠빌 입구',
#  '2089.사당역10번출구(금강빌딩)',
#  '209. 유진투자증권빌딩 앞',
#  '2090.기아자동차 사당점 앞',
#  '2091. 이수역9번출구',
#  '2092.흑석한강푸르지오(110동)',
#  '2093.상도SH빌아파트 입구',
#  '2094.숭실대학교(중문) ',
#  '2095.경문고등학교 앞',
#  '2096.서울특별시 동작관악교육지원청',
#  '2102. 봉림교 교통섬',
#  '2103. 신림동 우방아파트',
#  '2104. 사당역 5번출구',
#  '2105. 미성동 신림체육센터',
#  '2106. 세이브마트',
#  '2108. 은천치안센터',
#  '2109. 은천로입구 가로공원',
#  '2110. 조원동 미성아파트',
#  '2111. 서울대입구역 1번출구',
#  '2112. 서울대입구역 마에스트로',
#  '2115. 관악구시설관리공단',
#  '2116. 에이스에이존빌딩',
#  '2119. 중앙동 동진빌딩',
#  '2122. 낙성대로 입구',
#  '2127. 난곡종점',
#  '2128. 관악구청교차로',
#  '2129. 낙성대 과학전시관',
#  '213. KT앞',
#  '2130. 영어마을 관악캠프',
#  '2136. 신림역 8번출구',
#  '2137. KT&G 관악지점',
#  '2139. 서울신성초등학교',
#  '214. 금융감독원 앞',
#  '2140. 신림1교 교차로',
#  '2143. 서울산업정보학교',
#  '2144. 난우길입구',
#  '2145. 은천초등학교 육교',
#  '2148. 낙성대역 3번출구 뒤',
#  '215. 여의도고교 앞',
#  '2156. 신림푸르지오아파트',
#  '2159. 인헌초교',
#  '2164. 관악우체국',
#  '2165. JK장평타워',
#  '2167. 낙성대역 1번출구',
#  '2169. 봉천역 2번출구',
#  '217. NH농협은행 앞',
#  '2170. 조원동 강남힐병원',
#  '2171. 서울대입구역 5번출구',
#  '2172. 나들목공원',
#  '2173. 당곡사거리',
#  '2174. 삼성디지털프라자관악점',
#  '2175. 신림동걷고싶은문화의거리입구',
#  '2176. 보라매공원 보도육교',
#  '2177. 신대방역 2번 출구',
#  '2178. 서울대학교 정문',
#  '2179. 양녕로 입구',
#  '2183. 동방1교',
#  '2184. 구암초등학교 버스정류장',
#  '2185. 대학동 고시촌',
#  '2186. 낙성대입구삼거리',
#  '2187. 현대시장사거리',
#  '2189. 봉천역 4번출구',
#  '219. 롯데캐슬엠파이어 옆',
#  '2190.도원맨션',
#  '2191.대학동주민센터 ',
#  '2195.은천교회',
#  '2196. 봉천역 3번출구',
#  '2198.사랑의병원',
#  '2199.신봉천주유소 A',
#  '220. 미성아파트 A동 앞',
#  '2201. 본마을 정류소 앞',
#  '2202.청계산입구역 1번출구',
#  '2203. 청계산입구역 2번출구',
#  '2205. 내곡3단지 어린이공원 앞',
#  '2206. 언남초등학교 앞',
#  '2207. 내곡파출소 뒤 정자',
#  '221. 여의도초교 앞',
#  '2210. 반포1동 주민센터 앞',
#  '2211. 서초구립반포도서관 앞',
#  '2212.서초현대4차아파트 201동 맞은편',
#  '2213. 고속터미널역 5번출구 앞',
#  '2214. 신반포역 2번출구 앞',
#  '2215. 반포종합운동장 입구',
#  '2217.아크로리버뷰 부지 앞',
#  '2219. 고속터미널역 8-1번, 8-2번 출구 사이',
#  '222. 시범아파트버스정류장 옆',
#  '2221. 방일초교 마을버스 정류장',
#  '2222.사당역 12번출구 뒤',
#  '2223. 방배래미안 정문 앞',
#  '2225.백석예술대학교 제3캠퍼스 앞',
#  '2226. 신동아럭스빌아파트 앞',
#  '2227.방배열린문화센터 앞',
#  '2228.뒷벌공원 옆',
#  '2229.로고스교회 맞은 편',
#  '223. 진주아파트상가 앞',
#  '2230.이수역 4번 출구',
#  '2231. 삼성타운(삼성생명) A동 맞은편',
#  '2233. 서초신동아1차아파트 옆',
#  '2235.KT 서초지사 앞',
#  '2237.서울남부터미널 대합실 입구',
#  '2239.교대역 6번출구',
#  '224. 롯데캐슬 앞',
#  '2241.양재전화국 사거리',
#  '2242.양재역 10번 출구 앞',
#  '2243.서울가정법원',
#  '2244.교육개발원입구 교차로',
#  '2245.양재초등학교 맞은편',
#  '2246. 서울시 품질시험소 앞',
#  '2247.섬들근린공원',
#  '2248. 서초리슈빌S 글로벌 앞',
#  '2249. 우솔초등학교 맞은편',
#  '225. 앙카라공원 앞',
#  '2250. 서초유치원 맞은편',
#  '2251. 더케이호텔 입구(양재2) ',
#  '2252. 잔디마을 마을버스 정류장',
#  '2255. 양재시민의숲역 1번출구',
#  '2256.양재동 꽃시장 입구',
#  '2257. 청계산 입구 삼거리',
#  '2258.구룡사 삼거리',
#  '2259. 잠원역 3번-4번 출구사이 ',
#  '226. 샛강역 1번출구 앞',
#  '2263. 바우뫼문화복지회관',
#  '2264. 이수역 1번출구',
#  '2265. 이수고가차도 남단',
#  '2266. 서초역 3번출구',
#  '2268. 서초4동주민센터 ',
#  '2269. 주홍교 하부',
#  '227. 양평2나들목 보행통로 입구',
#  '2270. 서초포레스타 7단지',
#  '2271. 내방역 8번출구 앞',
#  '2272. 교대입구 교차로',
#  '2273. 일동제약 사거리',
#  '2274. 양재시민의숲역 3번출구',
#  '2275. 염곡치안센터 건너편',
#  '2276. 영동1교 (양재천근린공원)',
#  '2277. 길마중4교 하부',
#  '2279. 교대역 5번출구뒤',
#  '228. 선유도역 3번출구 앞',
#  '2280. 서울서초고용센터앞',
#  '2281. 연세사랑병원신관앞',
#  '2283. 그룹한빌딩옆',
#  '2284. CJ오쇼핑앞',
#  '2285. LH서초3단지 301동 맞은편',
#  '2286. 탑성마을입구',
#  '2287. 능안마을입구',
#  '2288. 안골마을입구',
#  '2289. 남태령역 2번출구',
#  '229. 양평1 보행육교 앞',
#  '2293. SPC 앞',
#  '2294. 두상빌딩 앞',
#  '2297. 남부터미널역 1번출구',
#  '2299. 한전아트센터 앞',
#  '230. 영등포구청역 1번출구',
#  '2301. 현대고등학교 건너편',
#  '2302. 교보타워 버스정류장(신논현역 3번출구 후면)',
#  '2303. 논현역 10번출구',
#  '2304. 대현그린타워',
#  '2305. MCM 본사 직영점 앞',
#  '2306. 압구정역 2번 출구 옆',
#  '2307. 압구정 한양 3차 아파트',
#  '2308. 압구정파출소 앞',
#  '2309. 청담역(우리들병원 앞)',
#  '231. 남부고용노동지청 남측',
#  '2310. 청담동 맥도날드 옆(위치)',
#  '2311. 학동로 래미안 아파트 앞',
#  '2312. 청담역 13번 출구 앞',
#  '2313. 금원빌딩 앞',
#  '2314. 청담나들목입구',
#  '2315. 봉은사역 5번출구 옆',
#  '2317. 삼성도로공원',
#  '2318. 삼성중앙역4번출구(문화센터더 리빌)',
#  '2319. 포스코사거리 서측(수협 삼성동 지점)',
#  '232. 양평우림 이비즈센타 앞',
#  '2320. 도곡역 대치지구대 방향',
#  '2321. 학여울역 사거리',
#  '2323. 주식회사 오뚜기 정문 앞',
#  '2324. 천주교 대치 2동 교회 옆',
#  '2325. 대치삼성아파트 앞 교차로',
#  '2326. 대치동 삼성로',
#  '2327. 뱅뱅사거리 랜드마크타워 앞',
#  '2328. 르네상스 호텔 사거리 역삼지하보도 7번출구 앞',
#  '2329. 르네상스호텔사거리 역삼지하보도 2번출구',
#  '233. 양평1동 YP센터 앞',
#  '2330. 역삼월드메르디앙아파트 앞',
#  '2331. 동영문화센터앞',
#  '2332. 선릉역3번출구',
#  '2333. 양재역 3번출구 주변',
#  '2334. 삼호아파트 2동 ( 간선도로)',
#  '2335. 3호선 매봉역 3번출구앞',
#  '2336. 강남세브란스교차로  래미안그레이튼 104동 앞',
#  '2337. 대모산입구역 2번출구 앞',
#  '2339. 현대아파트 정문 앞',
#  '2340. 삼호물산버스정류장(23370) 옆',
#  '2341. 일원역 4~5번 출구 사이',
#  '2342. 대청역 1번출구  뒤',
#  '2343. 세곡사거리 대왕파출소 앞',
#  '2344. 리엔파크 2단지 앞',
#  '2347. 두산건설 본사',
#  '2348. 포스코사거리(기업은행)',
#  '2349. 역삼빌딩 앞(하나은행 옆)',
#  '235. 신길동 우리은행 옆',
#  '2350. 래미안그레이튼102동앞',
#  '2351. 청소년수련관(수영장)앞',
#  '2352. 서울본부세관(건설회관 앞)',
#  '2353. 강남구청역 2번출구 뒤',
#  '2354. 청담역 2번출구',
#  '2356. 강남구청',
#  '2357. 르네상스호텔사거리 역삼지하보도 3번출구 앞 (더 오번 빌딩 명동칼국수 앞)',
#  '2358. 구룡초사거리 (현대아파트10동 앞 )',
#  '2359. 국립국악중,고교 정문 맞은편',
#  '236. 문래동자이아파트 앞',
#  '2360. 도곡1동 주민센터 교차로',
#  '2362. 신사동 가로수길 입구',
#  '2363. 강남 을지병원 교차로',
#  ...]

# %%
# 반복문 이해하기
lat_list = []  # 위도
long_list = [] # 경도

for name in summary_data["대여소명"].tolist():
    try:
        lat_value = sub_data.loc[sub_data["대여소명"]==name, "위도"].values
        long_value = sub_data.loc[sub_data["대여소명"]==name, "경도"].values
        print(lat_value)
    except:
        pass
# Out:
# [37.54179382]
# [37.5452652]
# [37.54395676]
# [37.55332947]
# [37.55486679]
# [37.55955887]
# [37.54935455]
# [37.53866577]
# [37.53450775]
# [37.53474426]
# [37.53600693]
# [37.53071594]
# [37.55003738]
# [37.55939865]
# [37.53544617]
# [37.52425385]
# [37.52679443]
# [37.5556488]
# [37.52825165]
# [37.56427383]
# [37.61978149]
# [37.60980225]
# [37.62265015]
# [37.6257782]
# [37.64260864]
# [37.59441376]
# [37.60036087]
# [37.64318466]
# [37.63825226]
# [37.61096954]
# [37.63925934]
# [37.6128006]
# [37.61654282]
# [37.59347916]
# [37.60944748]
# [37.60849762]
# [37.64208984]
# [37.64339447]
# [37.60232925]
# [37.63734818]
# [37.62672043]
# [37.59036255]
# [37.64350891]
# [37.63310242]
# [37.60100937]
# [37.59186172]
# [37.60412598]
# [37.59580994]
# [37.60119247]
# [37.59181213]
# [37.6567688]
# [37.65828705]
# [37.63028717]
# [37.61050797]
# [37.63140869]
# [37.59996796]

# %%
lat_value = sub_data.loc[sub_data["대여소명"]==name, "위도"].values
print(lat_value)
# Out:
# [37.59996796]

# %%
# 반복문 이해하기
lat_list = []  # 위도
long_list = [] # 경도

for name in summary_data["대여소명"].tolist():
    try:
        lat_value = sub_data.loc[sub_data["대여소명"]==name, "위도"].values[0]
        long_value = sub_data.loc[sub_data["대여소명"]==name, "경도"].values[0]
        # print(lat_value, long_value)
    except Exception as e:
        lat_value = None
        long_value = None
        print(e)
# Out:
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0

# %%
# 반복문 이해하기
lat_list = []  # 위도
long_list = [] # 경도

for name in summary_data["대여소명"].tolist():
    try:
        lat_value = sub_data.loc[sub_data["대여소명"]==name, "위도"].values[0]
        long_value = sub_data.loc[sub_data["대여소명"]==name, "경도"].values[0]
        # print(lat_value, long_value)

    except Exception as e:
        lat_value = None
        long_value = None
        # print("데이터를 찾을 수 없습니다.")

    lat_list.append(lat_value)
    long_list.append(long_value)

summary_data["위도"] = lat_list
summary_data["경도"] = long_list

summary_data
# Out:
#                            대여소명      이동거리(M)  이용시간(분)   이용건수         위도  \
# 0     1001. 광진교 남단 사거리(천호공원 방면)  22579951.13   212018   9762  37.541794
# 1               1002. 해공공원(천호동)  37190390.67   349509  15322  37.545265
# 2                  1003. 해공도서관앞  14033033.55   155349   7385  37.543957
# 3          1004. 삼성광나루아파트 버스정류장  32114486.56   309776  10468  37.553329
# 4              1006. 롯데캐슬 115동앞   2869819.58    26311   1540  37.554867
# ...                         ...          ...      ...    ...        ...
# 2780              992.북한산입구 정류장   3876214.34    28775    993  37.658287
# 2781          993.은평뉴타운 은뜨락아파트앞   3651995.73    37174   2097  37.630287
# 2782         994.북한산생태공원입구(교통섬)   2842205.41    24495   1639  37.610508
# 2783               995.은평다목적체육관   4923604.57    44168   2544  37.631409
# 2784         996.응암역2번출구 국민은행 앞  56014496.29   503169  22174  37.599968
#
#               경도
# 0     127.124748
# 1     127.125938
# 2     127.125488
# 3     127.128868
# 4     127.142799
# ...          ...
# 2780  126.945297
# 2781  126.919563
# 2782  126.938538
# 2783  126.925407
# 2784  126.915726
#
# [2785 rows x 6 columns]

# %%
# summary_data에서 이동거리가 많은 순으로 Top10 뽑기 data_d_top10
data_d_top10 = summary_data.sort_values(by="이동거리(M)", ascending=False).head(10)
data_d_top10
# Out:
#                          대여소명       이동거리(M)  이용시간(분)   이용건수         위도  \
# 1829         4217. 한강공원 망원나들목  3.539830e+08  2814405  65749  37.555576
# 2301  502. 자양(뚝섬한강공원)역 1번출구 앞  2.455384e+08  2074352  63557  37.531860
# 774         207. 여의나루역 1번출구 앞  2.027993e+08  1648615  39038  37.527157
# 2459          583. 청계천 생태교실 앞  1.935874e+08  1235396  30419  37.567970
# 2423            565. 옥수역 3번출구  1.932620e+08  1276284  29066  37.541367
# 1193               272. 당산육갑문  1.804158e+08  1322940  34325  37.535339
# 1188        2715.마곡나루역 2번 출구   1.395554e+08  1222774  98439  37.566925
# 796             2102. 봉림교 교통섬  1.380883e+08  1009331  38268  37.484085
# 178   1210. 롯데월드타워(잠실역2번출구 쪽)  1.274169e+08  1198697  61994  37.513126
# 1409           3511. 응봉역 1번출구  1.208717e+08   832153  21577  37.551250
#
#               경도
# 1829  126.896889
# 2301  127.067192
# 774   126.931900
# 2459  127.046890
# 2423  127.017761
# 1193  126.903679
# 1188  126.827438
# 796   126.926888
# 178   127.100960
# 1409  127.035103

# %%
# summary_data에서 이용시간이 많은 순으로 Top10 뽑기 data_t_top10
data_t_top10 = summary_data.sort_values(by="이용시간(분)", ascending=False).head(10)
data_t_top10
# Out:
#                          대여소명       이동거리(M)  이용시간(분)   이용건수         위도  \
# 1829         4217. 한강공원 망원나들목  3.539830e+08  2814405  65749  37.555576
# 2301  502. 자양(뚝섬한강공원)역 1번출구 앞  2.455384e+08  2074352  63557  37.531860
# 774         207. 여의나루역 1번출구 앞  2.027993e+08  1648615  39038  37.527157
# 1193               272. 당산육갑문  1.804158e+08  1322940  34325  37.535339
# 2423            565. 옥수역 3번출구  1.932620e+08  1276284  29066  37.541367
# 2459          583. 청계천 생태교실 앞  1.935874e+08  1235396  30419  37.567970
# 1188        2715.마곡나루역 2번 출구   1.395554e+08  1222774  98439  37.566925
# 178   1210. 롯데월드타워(잠실역2번출구 쪽)  1.274169e+08  1198697  61994  37.513126
# 796             2102. 봉림교 교통섬  1.380883e+08  1009331  38268  37.484085
# 938          230. 영등포구청역 1번출구  7.260118e+07   946392  52836  37.524635
#
#               경도
# 1829  126.896889
# 2301  127.067192
# 774   126.931900
# 1193  126.903679
# 2423  127.017761
# 2459  127.046890
# 1188  126.827438
# 178   127.100960
# 796   126.926888
# 938   126.896217

# %%
# summary_data에서 이용건수가 많은 순으로 Top10 뽑기 data_c_top10
data_c_top10 = summary_data.sort_values(by="이용건수", ascending=False).head(10)
data_c_top10
# Out:
#                          대여소명       이동거리(M)  이용시간(분)   이용건수         위도  \
# 1188        2715.마곡나루역 2번 출구   1.395554e+08  1222774  98439  37.566925
# 1200         2728.마곡나루역 3번 출구  9.318509e+07   752838  65977  37.565804
# 1829         4217. 한강공원 망원나들목  3.539830e+08  2814405  65749  37.555576
# 2301  502. 자양(뚝섬한강공원)역 1번출구 앞  2.455384e+08  2074352  63557  37.531860
# 178   1210. 롯데월드타워(잠실역2번출구 쪽)  1.274169e+08  1198697  61994  37.513126
# 1175      2701. 마곡나루역 5번출구 뒤편  6.483893e+07   529924  59768  37.565201
# 124   1153. 발산역 1번, 9번 인근 대여소  8.286086e+07   750695  55671  37.558949
# 938          230. 영등포구청역 1번출구  7.260118e+07   946392  52836  37.524635
# 1428   3533. 건대입구역 사거리(롯데백화점)  8.230525e+07   864711  40457  37.539295
# 101         1124. 발산역 6번 출구 뒤  5.854875e+07   599263  40233  37.558178
#
#               경도
# 1188  126.827438
# 1200  126.828079
# 1829  126.896889
# 2301  127.067192
# 178   127.100960
# 1175  126.827316
# 124   126.837173
# 938   126.896217
# 1428  127.070786
# 101   126.838455

# %% [markdown]
# ### 지도 시각화

# %%
import folium

# 지도 출력하기
center = [37.565516, 126.978025] # 중심 위치
map = folium.Map(location=center, zoom_start=12)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8a58c06f8cd8d3bba2b4a24bbe72838 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8a58c06f8cd8d3bba2b4a24bbe72838&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8a58c06f8cd8d3bba2b4a24bbe72838 = L.map(
#                 &quot;map_c8a58c06f8cd8d3bba2b4a24bbe72838&quot;,
#                 {
#                     center: [37.565516, 126.978025],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33c90723ea36f76e26f0c3d762ddbdae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_33c90723ea36f76e26f0c3d762ddbdae.addTo(map_c8a58c06f8cd8d3bba2b4a24bbe72838);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 이동거리 Top10 표시하기

# %%
for i in range(len(data_d_top10)):
    temp = data_d_top10.iloc[i]
    lat, lng = temp[["위도", "경도"]]

    folium.Marker(location=[lat, lng], icon=folium.Icon(color="red"), popup=temp.name).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8a58c06f8cd8d3bba2b4a24bbe72838 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8a58c06f8cd8d3bba2b4a24bbe72838&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8a58c06f8cd8d3bba2b4a24bbe72838 = L.map(
#                 &quot;map_c8a58c06f8cd8d3bba2b4a24bbe72838&quot;,
#                 {
#                     center: [37.565516, 126.978025],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33c90723ea36f76e26f0c3d762ddbdae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_33c90723ea36f76e26f0c3d762ddbdae.addTo(map_c8a58c06f8cd8d3bba2b4a24bbe72838);
#
#
#             tile_layer_33c90723ea36f76e26f0c3d762ddbdae.addTo(map_c8a58c06f8cd8d3bba2b4a24bbe72838);
#
#
#             var marker_7a6d038d5b6ac98589450515086cc95f = L.marker(
#                 [37.55557632, 126.89688873],
#                 {
# }
#             ).addTo(map_c8a58c06f8cd8d3bba2b4a24bbe72838);
#
#
#             var icon_1caa9f0ea4dbc00560ba727e781de087 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0af8a775dde4999caa1cdef44615d53e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba280ecf92ef713e823bed9179c8352f = $(`&lt;div id=&quot;html_ba280ecf92ef713e823bed9179c8352f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1829&lt;/div&gt;`)[0];
#                 popup_0af8a775dde4999caa1cdef44615d53e.setContent(html_ba280ecf92ef713e823bed9179c8352f);
#
#
#
#         marker_7a6d038d5b6ac98589450515086cc95f.bindPopup(popup_0af8a775dde4999caa1cdef44615d53e)
#         ;
#
#
#
#
#                 marker_7a6d038d5b6ac98589450515086cc95f.setIcon(icon_1caa9f0ea4dbc00560ba727e781de087);
#
#
#             var marker_bfc312ce89b5ca208d6fb45302affded = L.marker(
#                 [37.53186035, 127.06719208],
#                 {
# }
#             ).addTo(map_c8a58c06f8cd8d3bba2b4a24bbe72838);
#
#
#             var icon_c287b01e69dbfc69637b4334b668b5a4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_30b45c379135790436584c9d3350e99c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b04591a1ebc4f27eb8344e8a860c329 = $(`&lt;div id=&quot;html_7b04591a1ebc4f27eb8344e8a860c329&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2301&lt;/div&gt;`)[0];
#                 popup_30b45c379135790436584c9d3350e99c.setContent(html_7b04591a1ebc4f27eb8344e8a860c329);
#
#
#
#         marker_bfc312ce89b5ca208d6fb45302affded.bindPopup(popup_30b45c379135790436584c9d3350e99c)
#         ;
#
#
#
#
#                 marker_bfc312ce89b5ca208d6fb45302affded.setIcon(icon_c287b01e69dbfc69637b4334b668b5a4);
#
#
#             var marker_083bb988f8b4a8dfb519b28d4fe90e2c = L.marker(
#                 [37.52715683, 126.93190002],
#                 {
# }
#             ).addTo(map_c8a58c06f8cd8d3bba2b4a24bbe72838);
#
#
#             var icon_e26a66420cbc3db4a8ef463f459cf2c5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d848d95794f8cc9152537491cb7fa5d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adb013f8e8fa07690a618e920577f240 = $(`&lt;div id=&quot;html_adb013f8e8fa07690a618e920577f240&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;774&lt;/div&gt;`)[0];
#                 popup_d848d95794f8cc9152537491cb7fa5d0.setContent(html_adb013f8e8fa07690a618e920577f240);
#
#
#
#         marker_083bb988f8b4a8dfb519b28d4fe90e2c.bindPopup(popup_d848d95794f8cc9152537491cb7fa5d0)
#         ;
#
#
#
#
#                 marker_083bb988f8b4a8dfb519b28d4fe90e2c.setIcon(ic

# %% [markdown]
# #### 이용시간 Top10 표시하기
#
# > 인용구 추가

# %%
print(len(data_t_top10))
# Out:
# 10

# %%
for i in range(len(data_t_top10)):
    temp = data_t_top10.iloc[i]
    lat, long = temp[["위도", "경도"]]
    print(temp)
# Out:
# 대여소명       4217. 한강공원 망원나들목
# 이동거리(M)        353982957.41
# 이용시간(분)             2814405
# 이용건수                  65749
# 위도                37.555576
# 경도               126.896889
# Name: 1829, dtype: object
# 대여소명       502. 자양(뚝섬한강공원)역 1번출구 앞
# 이동거리(M)               245538424.26
# 이용시간(분)                    2074352
# 이용건수                         63557
# 위도                        37.53186
# 경도                      127.067192
# Name: 2301, dtype: object
# 대여소명       207. 여의나루역 1번출구 앞
# 이동거리(M)         202799251.15
# 이용시간(분)              1648615
# 이용건수                   39038
# 위도                 37.527157
# 경도                  126.9319
# Name: 774, dtype: object
# 대여소명         272. 당산육갑문
# 이동거리(M)    180415804.89
# 이용시간(분)         1322940
# 이용건수              34325
# 위도            37.535339
# 경도           126.903679
# Name: 1193, dtype: object
# 대여소명       565. 옥수역 3번출구
# 이동거리(M)     193262033.89
# 이용시간(분)          1276284
# 이용건수               29066
# 위도             37.541367
# 경도            127.017761
# Name: 2423, dtype: object
# 대여소명       583. 청계천 생태교실 앞
# 이동거리(M)       193587437.89
# 이용시간(분)            1235396
# 이용건수                 30419
# 위도                37.56797
# 경도               127.04689
# Name: 2459, dtype: object
# 대여소명       2715.마곡나루역 2번 출구
# 이동거리(M)         139555396.14
# 이용시간(분)              1222774
# 이용건수                   98439
# 위도                 37.566925
# 경도                126.827438
# Name: 1188, dtype: object
# 대여소명       1210. 롯데월드타워(잠실역2번출구 쪽)
# 이동거리(M)               127416881.12
# 이용시간(분)                    1198697
# 이용건수                         61994
# 위도                       37.513126
# 경도                       127.10096
# Name: 178, dtype: object
# 대여소명       2102. 봉림교 교통섬
# 이동거리(M)     138088349.36
# 이용시간(분)          1009331
# 이용건수               38268
# 위도             37.484085
# 경도            126.926888
# Name: 796, dtype: object
# 대여소명       230. 영등포구청역 1번출구
# 이동거리(M)         72601177.63
# 이용시간(분)              946392
# 이용건수                  52836
# 위도                37.524635
# 경도               126.896217
# Name: 938, dtype: object

# %%
print(data_d_top10["대여소명"])
# Out:
# 1829           4217. 한강공원 망원나들목
# 2301    502. 자양(뚝섬한강공원)역 1번출구 앞
# 774           207. 여의나루역 1번출구 앞
# 2459            583. 청계천 생태교실 앞
# 2423              565. 옥수역 3번출구
# 1193                 272. 당산육갑문
# 1188          2715.마곡나루역 2번 출구
# 796               2102. 봉림교 교통섬
# 178     1210. 롯데월드타워(잠실역2번출구 쪽)
# 1409             3511. 응봉역 1번출구
# Name: 대여소명, dtype: object

# %%
print(data_t_top10["대여소명"])
# Out:
# 1829           4217. 한강공원 망원나들목
# 2301    502. 자양(뚝섬한강공원)역 1번출구 앞
# 774           207. 여의나루역 1번출구 앞
# 1193                 272. 당산육갑문
# 2423              565. 옥수역 3번출구
# 2459            583. 청계천 생태교실 앞
# 1188          2715.마곡나루역 2번 출구
# 178     1210. 롯데월드타워(잠실역2번출구 쪽)
# 796               2102. 봉림교 교통섬
# 938            230. 영등포구청역 1번출구
# Name: 대여소명, dtype: object

# %%
print(data_c_top10["대여소명"])
# Out:
# 1188          2715.마곡나루역 2번 출구
# 1200           2728.마곡나루역 3번 출구
# 1829           4217. 한강공원 망원나들목
# 2301    502. 자양(뚝섬한강공원)역 1번출구 앞
# 178     1210. 롯데월드타워(잠실역2번출구 쪽)
# 1175        2701. 마곡나루역 5번출구 뒤편
# 124     1153. 발산역 1번, 9번 인근 대여소
# 938            230. 영등포구청역 1번출구
# 1428     3533. 건대입구역 사거리(롯데백화점)
# 101           1124. 발산역 6번 출구 뒤
# Name: 대여소명, dtype: object

# %%
# 지도 출력하기
center = [37.565516, 126.978025] # 중심 위치
map = folium.Map(location=center, zoom_start=12)
map

for i in range(len(data_t_top10)):
    temp = data_t_top10.iloc[i]
    name, lat, lng = temp[["대여소명", "위도", "경도"]]

    folium.Marker(location=[lat, lng], icon=folium.Icon(color="blue"), popup=name).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ad3f997edb584cffbfca411c48da3e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ad3f997edb584cffbfca411c48da3e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ad3f997edb584cffbfca411c48da3e7 = L.map(
#                 &quot;map_4ad3f997edb584cffbfca411c48da3e7&quot;,
#                 {
#                     center: [37.565516, 126.978025],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00b2fec21e5a32a5102470eef8ab071e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_00b2fec21e5a32a5102470eef8ab071e.addTo(map_4ad3f997edb584cffbfca411c48da3e7);
#
#
#             var marker_5a6c7e863d060ad072800c928102e083 = L.marker(
#                 [37.55557632, 126.89688873],
#                 {
# }
#             ).addTo(map_4ad3f997edb584cffbfca411c48da3e7);
#
#
#             var icon_11b70a5e5c75cbc9b10bbada0542a5a0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_666bed9fb0c52555dde728f7d9838bfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b3c457f99cd731134ac9e44422ab503 = $(`&lt;div id=&quot;html_7b3c457f99cd731134ac9e44422ab503&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4217. 한강공원 망원나들목&lt;/div&gt;`)[0];
#                 popup_666bed9fb0c52555dde728f7d9838bfd.setContent(html_7b3c457f99cd731134ac9e44422ab503);
#
#
#
#         marker_5a6c7e863d060ad072800c928102e083.bindPopup(popup_666bed9fb0c52555dde728f7d9838bfd)
#         ;
#
#
#
#
#                 marker_5a6c7e863d060ad072800c928102e083.setIcon(icon_11b70a5e5c75cbc9b10bbada0542a5a0);
#
#
#             var marker_cd83c046ca48c65ad98b6e028bf8429d = L.marker(
#                 [37.53186035, 127.06719208],
#                 {
# }
#             ).addTo(map_4ad3f997edb584cffbfca411c48da3e7);
#
#
#             var icon_d7cc89d21798947162f9a42acc34eeb6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4944697a1a96d9a46f0de49c402d9f73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96ffeaa4b36c2d85b35bbe2c5f0a608a = $(`&lt;div id=&quot;html_96ffeaa4b36c2d85b35bbe2c5f0a608a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;502. 자양(뚝섬한강공원)역 1번출구 앞&lt;/div&gt;`)[0];
#                 popup_4944697a1a96d9a46f0de49c402d9f73.setContent(html_96ffeaa4b36c2d85b35bbe2c5f0a608a);
#
#
#
#         marker_cd83c046ca48c65ad98b6e028bf8429d.bindPopup(popup_4944697a1a96d9a46f0de49c402d9f73)
#         ;
#
#
#
#
#                 marker_cd83c046ca48c65ad98b6e028bf8429d.setIcon(icon_d7cc89d21798947162f9a42acc34eeb6);
#
#
#             var marker_f6037804260d70e9d52ab15a9970fad1 = L.marker(
#                 [37.52715683, 126.93190002],
#                 {
# }
#             ).addTo(map_4ad3f997edb584cffbfca411c48da3e7);
#
#
#             var icon_3bd69486abe56560eb524413483640f9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4e9d2fc36e1513e4f2378dae666fa9a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51fdd6f874656e67a3983b611faa69b0 = $(`&lt;div id=&quot;html_51fdd6f874656e67a3983b611faa69b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;207. 여의나루역 1번출구 앞&lt;/div&gt;`)[0];
#                 popup_4e9d2fc36e1513e4f2378dae666fa9a7.setContent(html_51fdd6f874656e67a3983b611faa69b0);
#
#
#
#         marker_f6037804260d70e9d52ab15a9970fad1.bindPopup(popup_4e9d2fc36e1513e4f2378dae666fa9a7)
#         ;
#
#
#
#
#                 marker_f6037804260d70e9d52ab15a9970fad1.setIcon(icon_3bd69486abe56560eb524413483640f9);

# %% [markdown]
# #### 이용건수 Top10 표시하기

# %%
# 지도 출력하기
center = [37.565516, 126.978025] # 중심 위치
map = folium.Map(location=center, zoom_start=12)
map

for i in range(len(data_c_top10)):
    temp = data_c_top10.iloc[i]
    # print(temp)
    name, lat, lng = temp[["대여소명", "위도", "경도"]]

    folium.Marker(location=[lat, lng], icon=folium.Icon(color="green"), popup=name).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1aa3661489a0330b93d1303bd27531dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1aa3661489a0330b93d1303bd27531dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1aa3661489a0330b93d1303bd27531dc = L.map(
#                 &quot;map_1aa3661489a0330b93d1303bd27531dc&quot;,
#                 {
#                     center: [37.565516, 126.978025],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_730c500ddc47f5ae5e7183cd4cd62230 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_730c500ddc47f5ae5e7183cd4cd62230.addTo(map_1aa3661489a0330b93d1303bd27531dc);
#
#
#             var marker_74140996c8d6ea98467db4add90c1a0b = L.marker(
#                 [37.56692505, 126.82743835],
#                 {
# }
#             ).addTo(map_1aa3661489a0330b93d1303bd27531dc);
#
#
#             var icon_69858dbe3ff55606d97afc9d95aaffbd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c54764747e78c4cec6b72e70726c69e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcf51442b4866622f4cbfffeefb24dec = $(`&lt;div id=&quot;html_dcf51442b4866622f4cbfffeefb24dec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2715.마곡나루역 2번 출구 &lt;/div&gt;`)[0];
#                 popup_c54764747e78c4cec6b72e70726c69e5.setContent(html_dcf51442b4866622f4cbfffeefb24dec);
#
#
#
#         marker_74140996c8d6ea98467db4add90c1a0b.bindPopup(popup_c54764747e78c4cec6b72e70726c69e5)
#         ;
#
#
#
#
#                 marker_74140996c8d6ea98467db4add90c1a0b.setIcon(icon_69858dbe3ff55606d97afc9d95aaffbd);
#
#
#             var marker_087c925f78b16857f0f0c5b32847210d = L.marker(
#                 [37.56580353, 126.82807922],
#                 {
# }
#             ).addTo(map_1aa3661489a0330b93d1303bd27531dc);
#
#
#             var icon_b24ec35dff89b36bec1ea1b5b1fecffe = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_dcb2dc5ed1ccceb3035e85cf4901c42a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a09dc4f6a0acfd34d87fd8aa476c763 = $(`&lt;div id=&quot;html_0a09dc4f6a0acfd34d87fd8aa476c763&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2728.마곡나루역 3번 출구&lt;/div&gt;`)[0];
#                 popup_dcb2dc5ed1ccceb3035e85cf4901c42a.setContent(html_0a09dc4f6a0acfd34d87fd8aa476c763);
#
#
#
#         marker_087c925f78b16857f0f0c5b32847210d.bindPopup(popup_dcb2dc5ed1ccceb3035e85cf4901c42a)
#         ;
#
#
#
#
#                 marker_087c925f78b16857f0f0c5b32847210d.setIcon(icon_b24ec35dff89b36bec1ea1b5b1fecffe);
#
#
#             var marker_9e53d3c8dd44f77bf1a9e4a5a0d0654c = L.marker(
#                 [37.55557632, 126.89688873],
#                 {
# }
#             ).addTo(map_1aa3661489a0330b93d1303bd27531dc);
#
#
#             var icon_85d42160db6748ce92dea438258ee105 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5f0d4fabc5868b3fc4847896a6a0805e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23663e03ff5d28520de96aca738d87ca = $(`&lt;div id=&quot;html_23663e03ff5d28520de96aca738d87ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4217. 한강공원 망원나들목&lt;/div&gt;`)[0];
#                 popup_5f0d4fabc5868b3fc4847896a6a0805e.setContent(html_23663e03ff5d28520de96aca738d87ca);
#
#
#
#         marker_9e53d3c8dd44f77bf1a9e4a5a0d0654c.bindPopup(popup_5f0d4fabc5868b3fc4847896a6a0805e)
#         ;
#
#
#
#
#                 marker_9e53d3c8dd44f77bf1a9e4a5a0d0654c.setIcon(icon_85d42160db6748ce92dea438258ee105);
#
#
#             var
